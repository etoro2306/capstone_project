# %% [markdown]
# # Image Captioning
#
# **Author:** [A_K_Nain](https://twitter.com/A_K_Nain)<br>
# **Date created:** 2021/05/29<br>
# **Last modified:** 2021/10/31<br>
# **Description:** Implement an image captioning model using a CNN and a Transformer.

# %% [markdown]
# ## Setup

# %%
import os
import re
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.applications import efficientnet
from tensorflow.keras.layers import TextVectorization


seed = 123
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# ## Download the dataset
#
# We will be using the Flickr8K dataset for this tutorial. This dataset comprises over
# 8,000 images, that are each paired with five different captions.

# %%
# !git clone https://github.com/etoro2306/capstone_project.git
# Out:
# Cloning into 'capstone_project'...
# remote: Enumerating objects: 517, done.
# remote: Counting objects: 100% (406/406), done.
# remote: Compressing objects: 100% (336/336), done.
# remote: Total 517 (delta 130), reused 305 (delta 66), pack-reused 111
# Receiving objects: 100% (517/517), 61.22 MiB | 6.08 MiB/s, done.
# Resolving deltas: 100% (134/134), done.

# %%
# %cd capstone_project/
# Out:
# /content/capstone_project

# %%
# !git checkout dev
# Out:
# Branch 'dev' set up to track remote branch 'dev' from 'origin'.
# Switched to a new branch 'dev'

# %%
# %cd ../..
# Out:
# /

# %%
# Path to the images
IMAGES_PATH = "/content/capstone_project/Image_captioning/image_data"

# Desired image dimensions
IMAGE_SIZE = (299, 505)

# Vocabulary size
VOCAB_SIZE = 4000

# Fixed length allowed for any sequence
SEQ_LENGTH = 30

# Dimension for the image embeddings and token embeddings
EMBED_DIM = 512

# Per-layer units in the feed-forward network
FF_DIM = 512

# Other training parameters
BATCH_SIZE = 64
EPOCHS = 200
AUTOTUNE = tf.data.AUTOTUNE

# %% [markdown]
# ## Preparing the dataset

# %%
def load_captions_data(filename):
    """Loads captions (text) data and maps them to corresponding images.

    Args:
        filename: Path to the text file containing caption data.

    Returns:
        caption_mapping: Dictionary mapping image names and the corresponding captions
        text_data: List containing all the available captions
    """

    with open(filename, encoding = "latin-1") as caption_file:
        caption_data = caption_file.readlines()
        caption_mapping = {}
        text_data = []
        images_to_skip = set()

        for line in caption_data:
            line = line.rstrip("\n")
            # Image name and captions are separated using a tab
            img_name, caption = line.split("\t")

            # Each image is repeated five times for the five different captions.
            # Each image name has a suffix `#(caption_number)`
            img_name = img_name.split("#")[0]
            img_name = os.path.join(IMAGES_PATH, img_name.strip())

            # We will remove caption that are either too short to too long
            tokens = caption.strip().split()

            if len(tokens) < 5 or len(tokens) > SEQ_LENGTH:
                images_to_skip.add(img_name)
                continue

            if img_name.endswith("jpg") and img_name not in images_to_skip:
                # We will add a start and an end token to each caption
                caption = "<start> " + caption.strip() + " <end>"
                text_data.append(caption)

                if img_name in caption_mapping:
                    caption_mapping[img_name].append(caption)
                else:
                    caption_mapping[img_name] = [caption]

        for img_name in images_to_skip:
            if img_name in caption_mapping:
                del caption_mapping[img_name]

        return caption_mapping, text_data


def train_val_split(caption_data, train_size=0.8, shuffle=True):
    """Split the captioning dataset into train and validation sets.

    Args:
        caption_data (dict): Dictionary containing the mapped caption data
        train_size (float): Fraction of all the full dataset to use as training data
        shuffle (bool): Whether to shuffle the dataset before splitting

    Returns:
        Traning and validation datasets as two separated dicts
    """

    # 1. Get the list of all image names
    all_images = list(caption_data.keys())

    # 2. Shuffle if necessary
    if shuffle:
        np.random.shuffle(all_images)

    # 3. Split into training and validation sets
    train_size = int(len(caption_data) * train_size)

    training_data = {
        img_name: caption_data[img_name] for img_name in all_images[:train_size]
    }
    validation_data = {
        img_name: caption_data[img_name] for img_name in all_images[train_size:]
    }

    # 4. Return the splits
    return training_data, validation_data


# Load the dataset
captions_mapping, text_data = load_captions_data("/content/capstone_project/Image_captioning/newcaptions.txt")

# Split the dataset into training and validation sets
train_data, valid_data = train_val_split(captions_mapping)
print("Number of training samples: ", len(train_data))
print("Number of validation samples: ", len(valid_data))
# Out:
# Number of training samples:  147
# Number of validation samples:  37

# %% [markdown]
# ## Vectorizing the text data
#
# We'll use the `TextVectorization` layer to vectorize the text data,
# that is to say, to turn the
# original strings into integer sequences where each integer represents the index of
# a word in a vocabulary. We will use a custom string standardization scheme
# (strip punctuation characters except `<` and `>`) and the default
# splitting scheme (split on whitespace).

# %%
def custom_standardization(input_string):
    lowercase = tf.strings.lower(input_string)
    return tf.strings.regex_replace(lowercase, "[%s]" % re.escape(strip_chars), "")


strip_chars = "!\"#$%&'()*+,-./:;<=>?@[\]^_`{|}~"
strip_chars = strip_chars.replace("<", "")
strip_chars = strip_chars.replace(">", "")

vectorization = TextVectorization(
    max_tokens=VOCAB_SIZE,
    output_mode="int",
    output_sequence_length=SEQ_LENGTH,
    standardize=custom_standardization,
)
vectorization.adapt(text_data)

# Data augmentation for image data
image_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.2),
        layers.RandomContrast(0.3),
    ]
)

# %% [markdown]
# ## Building a `tf.data.Dataset` pipeline for training
#
# We will generate pairs of images and corresponding captions using a `tf.data.Dataset` object.
# The pipeline consists of two steps:
#
# 1. Read the image from the disk
# 2. Tokenize all the five captions corresponding to the image

# %%
def decode_and_resize(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, IMAGE_SIZE)
    img = tf.image.convert_image_dtype(img, tf.float32)
    return img


def process_input(img_path, captions):
    return decode_and_resize(img_path), vectorization(captions)


def make_dataset(images, captions):
    dataset = tf.data.Dataset.from_tensor_slices((images, captions))
    dataset = dataset.shuffle(BATCH_SIZE * 8)
    dataset = dataset.map(process_input, num_parallel_calls=AUTOTUNE)
    dataset = dataset.batch(BATCH_SIZE).prefetch(AUTOTUNE)

    return dataset


# Pass the list of images and the list of corresponding captions
train_dataset = make_dataset(list(train_data.keys()), list(train_data.values()))

valid_dataset = make_dataset(list(valid_data.keys()), list(valid_data.values()))

# %% [markdown]
# ## Building the model
#
# Our image captioning architecture consists of three models:
#
# 1. A CNN: used to extract the image features
# 2. A TransformerEncoder: The extracted image features are then passed to a Transformer
#                     based encoder that generates a new representation of the inputs
# 3. A TransformerDecoder: This model takes the encoder output and the text data
#                     (sequences) as inputs and tries to learn to generate the caption.

# %%
def get_cnn_model():
    base_model = efficientnet.EfficientNetB0(
        input_shape=(*IMAGE_SIZE, 3), include_top=False, weights="imagenet",
    )
    # We freeze our feature extractor
    base_model.trainable = False
    base_model_out = base_model.output
    base_model_out = layers.Reshape((-1, base_model_out.shape[-1]))(base_model_out)
    cnn_model = keras.models.Model(base_model.input, base_model_out)
    return cnn_model


class TransformerEncoderBlock(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention_1 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.0
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.dense_1 = layers.Dense(embed_dim, activation="relu")

    def call(self, inputs, training, mask=None):
        inputs = self.layernorm_1(inputs)
        inputs = self.dense_1(inputs)

        attention_output_1 = self.attention_1(
            query=inputs,
            value=inputs,
            key=inputs,
            attention_mask=None,
            training=training,
        )
        out_1 = self.layernorm_2(inputs + attention_output_1)
        return out_1


class PositionalEmbedding(layers.Layer):
    def __init__(self, sequence_length, vocab_size, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.token_embeddings = layers.Embedding(
            input_dim=vocab_size, output_dim=embed_dim
        )
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=embed_dim
        )
        self.sequence_length = sequence_length
        self.vocab_size = vocab_size
        self.embed_dim = embed_dim
        self.embed_scale = tf.math.sqrt(tf.cast(embed_dim, tf.float32))

    def call(self, inputs):
        length = tf.shape(inputs)[-1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_tokens = self.token_embeddings(inputs)
        embedded_tokens = embedded_tokens * self.embed_scale
        embedded_positions = self.position_embeddings(positions)
        return embedded_tokens + embedded_positions

    def compute_mask(self, inputs, mask=None):
        return tf.math.not_equal(inputs, 0)


class TransformerDecoderBlock(layers.Layer):
    def __init__(self, embed_dim, ff_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.ff_dim = ff_dim
        self.num_heads = num_heads
        self.attention_1 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.1
        )
        self.attention_2 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.1
        )
        self.ffn_layer_1 = layers.Dense(ff_dim, activation="relu")
        self.ffn_layer_2 = layers.Dense(embed_dim)

        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.layernorm_3 = layers.LayerNormalization()

        self.embedding = PositionalEmbedding(
            embed_dim=EMBED_DIM, sequence_length=SEQ_LENGTH, vocab_size=VOCAB_SIZE
        )
        self.out = layers.Dense(VOCAB_SIZE, activation="softmax")

        self.dropout_1 = layers.Dropout(0.3)
        self.dropout_2 = layers.Dropout(0.5)
        self.supports_masking = True

    def call(self, inputs, encoder_outputs, training, mask=None):
        inputs = self.embedding(inputs)
        causal_mask = self.get_causal_attention_mask(inputs)

        if mask is not None:
            padding_mask = tf.cast(mask[:, :, tf.newaxis], dtype=tf.int32)
            combined_mask = tf.cast(mask[:, tf.newaxis, :], dtype=tf.int32)
            combined_mask = tf.minimum(combined_mask, causal_mask)

        attention_output_1 = self.attention_1(
            query=inputs,
            value=inputs,
            key=inputs,
            attention_mask=combined_mask,
            training=training,
        )
        out_1 = self.layernorm_1(inputs + attention_output_1)

        attention_output_2 = self.attention_2(
            query=out_1,
            value=encoder_outputs,
            key=encoder_outputs,
            attention_mask=padding_mask,
            training=training,
        )
        out_2 = self.layernorm_2(out_1 + attention_output_2)

        ffn_out = self.ffn_layer_1(out_2)
        ffn_out = self.dropout_1(ffn_out, training=training)
        ffn_out = self.ffn_layer_2(ffn_out)

        ffn_out = self.layernorm_3(ffn_out + out_2, training=training)
        ffn_out = self.dropout_2(ffn_out, training=training)
        preds = self.out(ffn_out)
        return preds

    def get_causal_attention_mask(self, inputs):
        input_shape = tf.shape(inputs)
        batch_size, sequence_length = input_shape[0], input_shape[1]
        i = tf.range(sequence_length)[:, tf.newaxis]
        j = tf.range(sequence_length)
        mask = tf.cast(i >= j, dtype="int32")
        mask = tf.reshape(mask, (1, input_shape[1], input_shape[1]))
        mult = tf.concat(
            [tf.expand_dims(batch_size, -1), tf.constant([1, 1], dtype=tf.int32)],
            axis=0,
        )
        return tf.tile(mask, mult)


class ImageCaptioningModel(keras.Model):
    def __init__(
        self, cnn_model, encoder, decoder, num_captions_per_image=3, image_aug=None,
    ):
        super().__init__()
        self.cnn_model = cnn_model
        self.encoder = encoder
        self.decoder = decoder
        self.loss_tracker = keras.metrics.Mean(name="loss")
        self.acc_tracker = keras.metrics.Mean(name="accuracy")
        self.num_captions_per_image = num_captions_per_image
        self.image_aug = image_aug

    def calculate_loss(self, y_true, y_pred, mask):
        loss = self.loss(y_true, y_pred)
        mask = tf.cast(mask, dtype=loss.dtype)
        loss *= mask
        return tf.reduce_sum(loss) / tf.reduce_sum(mask)

    def calculate_accuracy(self, y_true, y_pred, mask):
        accuracy = tf.equal(y_true, tf.argmax(y_pred, axis=2))
        accuracy = tf.math.logical_and(mask, accuracy)
        accuracy = tf.cast(accuracy, dtype=tf.float32)
        mask = tf.cast(mask, dtype=tf.float32)
        return tf.reduce_sum(accuracy) / tf.reduce_sum(mask)

    def _compute_caption_loss_and_acc(self, img_embed, batch_seq, training=True):
        encoder_out = self.encoder(img_embed, training=training)
        batch_seq_inp = batch_seq[:, :-1]
        batch_seq_true = batch_seq[:, 1:]
        mask = tf.math.not_equal(batch_seq_true, 0)
        batch_seq_pred = self.decoder(
            batch_seq_inp, encoder_out, training=training, mask=mask
        )
        loss = self.calculate_loss(batch_seq_true, batch_seq_pred, mask)
        acc = self.calculate_accuracy(batch_seq_true, batch_seq_pred, mask)
        return loss, acc

    def train_step(self, batch_data):
        batch_img, batch_seq = batch_data
        batch_loss = 0
        batch_acc = 0

        if self.image_aug:
            batch_img = self.image_aug(batch_img)

        # 1. Get image embeddings
        img_embed = self.cnn_model(batch_img)

        # 2. Pass each of the five captions one by one to the decoder
        # along with the encoder outputs and compute the loss as well as accuracy
        # for each caption.
        for i in range(self.num_captions_per_image):
            with tf.GradientTape() as tape:
                loss, acc = self._compute_caption_loss_and_acc(
                    img_embed, batch_seq[:, i, :], training=True
                )

                # 3. Update loss and accuracy
                batch_loss += loss
                batch_acc += acc

            # 4. Get the list of all the trainable weights
            train_vars = (
                self.encoder.trainable_variables + self.decoder.trainable_variables
            )

            # 5. Get the gradients
            grads = tape.gradient(loss, train_vars)

            # 6. Update the trainable weights
            self.optimizer.apply_gradients(zip(grads, train_vars))

        # 7. Update the trackers
        batch_acc /= float(self.num_captions_per_image)
        self.loss_tracker.update_state(batch_loss)
        self.acc_tracker.update_state(batch_acc)

        # 8. Return the loss and accuracy values
        return {"loss": self.loss_tracker.result(), "acc": self.acc_tracker.result()}

    def test_step(self, batch_data):
        batch_img, batch_seq = batch_data
        batch_loss = 0
        batch_acc = 0

        # 1. Get image embeddings
        img_embed = self.cnn_model(batch_img)

        # 2. Pass each of the five captions one by one to the decoder
        # along with the encoder outputs and compute the loss as well as accuracy
        # for each caption.
        for i in range(self.num_captions_per_image):
            loss, acc = self._compute_caption_loss_and_acc(
                img_embed, batch_seq[:, i, :], training=False
            )

            # 3. Update batch loss and batch accuracy
            batch_loss += loss
            batch_acc += acc

        batch_acc /= float(self.num_captions_per_image)

        # 4. Update the trackers
        self.loss_tracker.update_state(batch_loss)
        self.acc_tracker.update_state(batch_acc)

        # 5. Return the loss and accuracy values
        return {"loss": self.loss_tracker.result(), "acc": self.acc_tracker.result()}

    @property
    def metrics(self):
        # We need to list our metrics here so the `reset_states()` can be
        # called automatically.
        return [self.loss_tracker, self.acc_tracker]


cnn_model = get_cnn_model()
encoder = TransformerEncoderBlock(embed_dim=EMBED_DIM, dense_dim=FF_DIM, num_heads=1)
decoder = TransformerDecoderBlock(embed_dim=EMBED_DIM, ff_dim=FF_DIM, num_heads=2)
caption_model = ImageCaptioningModel(
    cnn_model=cnn_model, encoder=encoder, decoder=decoder, image_aug=image_augmentation,
)

# %% [markdown]
# ## Model training

# %%
# Define the loss function
cross_entropy = keras.losses.SparseCategoricalCrossentropy(
    from_logits=False, reduction="none"
)

# EarlyStopping criteria
early_stopping = keras.callbacks.EarlyStopping(patience=3, restore_best_weights=True)


# Learning Rate Scheduler for the optimizer
class LRSchedule(keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, post_warmup_learning_rate, warmup_steps):
        super().__init__()
        self.post_warmup_learning_rate = post_warmup_learning_rate
        self.warmup_steps = warmup_steps

    def __call__(self, step):
        global_step = tf.cast(step, tf.float32)
        warmup_steps = tf.cast(self.warmup_steps, tf.float32)
        warmup_progress = global_step / warmup_steps
        warmup_learning_rate = self.post_warmup_learning_rate * warmup_progress
        return tf.cond(
            global_step < warmup_steps,
            lambda: warmup_learning_rate,
            lambda: self.post_warmup_learning_rate,
        )


# Create a learning rate schedule
num_train_steps = len(train_dataset) * EPOCHS
num_warmup_steps = num_train_steps // 15
lr_schedule = LRSchedule(post_warmup_learning_rate=1e-4, warmup_steps=num_warmup_steps)

# Compile the model
caption_model.compile(optimizer=keras.optimizers.Adam(lr_schedule), loss=cross_entropy)

# Fit the model

caption_model.fit(
    train_dataset,
    epochs=EPOCHS,
    validation_data=valid_dataset,
)
#caption_model.fit(
 #   train_dataset,
 #   epochs=EPOCHS,
 #   validation_data=valid_dataset,
 #   callbacks=[early_stopping],
#)
# Out:
# Epoch 1/200
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# 3/3 [==============================] - 25s 3s/step - loss: 25.4410 - acc: 0.0000e+00 - val_loss: 24.7307 - val_acc: 0.0000e+00
# Epoch 2/200
# 3/3 [==============================] - 4s 1s/step - loss: 24.4471 - acc: 0.0063 - val_loss: 23.0344 - val_acc: 0.1418
# Epoch 3/200
# 3/3 [==============================] - 4s 1s/step - loss: 22.2268 - acc: 0.1073 - val_loss: 20.0546 - val_acc: 0.1824
# Epoch 4/200
# 3/3 [==============================] - 4s 1s/step - loss: 19.3187 - acc: 0.1618 - val_loss: 17.2592 - val_acc: 0.1824
# Epoch 5/200
# 3/3 [==============================] - 4s 1s/step - loss: 16.8247 - acc: 0.1842 - val_loss: 15.0701 - val_acc: 0.1910
# Epoch 6/200
# 3/3 [==============================] - 5s 1s/step - loss: 14.7379 - acc: 0.2013 - val_loss: 13.3605 - val_acc: 0.2148
# Epoch 7/200
# 3/3 [==============================] - 4s 1s/step - loss: 13.2191 - acc: 0.2140 - val_loss: 12.1007 - val_acc: 0.2549
# Epoch 8/200
# 3/3 [==============================] - 4s 1s/step - loss: 12.1274 - acc: 0.2415 - val_loss: 11.1918 - val_acc: 0.2824
# Epoch 9/200
# 3/3 [==============================] - 5s 1s/step - loss: 11.2475 - acc: 0.2608 - val_loss: 10.5160 - val_acc: 0.2961
# Epoch 10/200
# 3/3 [==============================] - 3s 971ms/step - loss: 10.5895 - acc: 0.2915 - val_loss: 9.9635 - val_acc: 0.3526
# Epoch 11/200
# 3/3 [==============================] - 4s 1s/step - loss: 9.8792 - acc: 0.3194 - val_loss: 9.4702 - val_acc: 0.3753
# Epoch 12/200
# 3/3 [==============================] - 3s 930ms/step - loss: 9.5556 - acc: 0.3519 - val_loss: 9.0207 - val_acc: 0.3977
# Epoch 13/200
# 3/3 [==============================] - 3s 924ms/step - loss: 9.3079 - acc: 0.3803 - val_loss: 8.6221 - val_acc: 0.4101
# Epoch 14/200
# 3/3 [==============================] - 4s 1s/step - loss: 8.5938 - acc: 0.3925 - val_loss: 8.2785 - val_acc: 0.4290
# Epoch 15/200
# 3/3 [==============================] - 3s 862ms/step - loss: 8.4369 - acc: 0.4032 - val_loss: 8.0031 - val_acc: 0.4388
# Epoch 16/200
# 3/3 [==============================] - 4s 951ms/step - loss: 8.0633 - acc: 0.4216 - val_loss: 7.7466 - val_acc: 0.4321
# Epoch 17/200
# 3/3 [==============================] - 4s 1s/step - loss: 7.7569 - acc: 0.4239 - val_loss: 7.5062 - val_acc: 0.4436
# Epoch 18/200
# 3/3 [==============================] - 3s 968ms/step - loss: 7.6604 - acc: 0.4288 - val_loss: 7.3172 - val_acc: 0.4507
# Epoch 19/200
# 3/3 [==============================] - 3s 904ms/step - loss: 7.3412 - acc: 0.4431 - val_loss: 7.1600 - val_acc: 0.4467
# Epoch 20/200
# 3/3 [==============================] - 4s 1s/step - loss: 7.1907 - acc: 0.4549 - val_loss: 6.9627 - val_acc: 0.4668
# Epoch 21/200
# 3/3 [==============================] - 3s 898ms/step - loss: 6.9044 - acc: 0.4626 - val_loss: 6.8002 - val_acc: 0.4621
# Epoch 22/200
# 3/3 [==============================] - 3s 979ms/step - loss: 6.8355 - acc: 0.4670 - val_loss: 6.6377 - val_acc: 0.4767
# Epoch 23/200
# 3/3 [==============================] - 4s 1s/step - loss: 6.4165 - acc: 0.4791 - val_loss: 6.5306 - val_acc: 0.4857
# Epoch 24/200
# 3/3 [==============================] - 3s 937ms/step - loss: 6.2383 - acc: 0.4924 - val_loss: 6.3974 - val_acc: 0.4870
# Epoch 25/200
# 3/3 [==============================] - 4s 1s/step - loss: 6.0526 - acc: 0.5041 - val_loss: 6.2946 - val_acc: 0.4950
# Epoch 26/200
# 3/3 [==============================] - 3s 967ms/step - loss: 6.0110 - acc: 0.5144 - val_loss: 6.1756 - val_acc: 0.5066
# Epoch 27/200
# 3/3 [==============================] - 4s 988ms/step - loss: 5.9342 - acc: 0.5183 - val_loss: 6.0466 - val_acc: 0.5024
# Epoch 28/200
# 3/3 [==============================] - 4s 1s/step - loss: 5.6728 - acc: 0.5141 - val_loss: 5.9663 - val_acc: 0.5146
# Epoch 29/200
# 3/3 [==============================] - 3s 860ms/step - loss: 5.6906 - acc: 0.5278 - val_loss: 5.8242 - val_acc: 0.5066
# Epoch 30/200
# 3/3 [==============================] - 3s 970ms/step - loss: 5.5648 - acc: 0.5360 - val_loss: 5.7750 - val_acc: 0.5129
# Epoch 31/200
# 3/3 [==============================] - 4s 1s/step - loss: 5.3063 - acc: 0.5385 - val_loss: 5.6738 - val_acc: 0.5274
# Epoch 32/200
# 3/3 [==============================] - 3s 870ms/step - loss: 5.0794 - acc: 0.5553 - val_loss: 5.6546 - val_acc: 0.5284
# Epoch 33/200
# 3/3 [==============================] - 4s 995ms/step - loss: 5.1327 - acc: 0.5636 - val_loss: 5.5692 - val_acc: 0.5251
# Epoch 34/200
# 3/3 [==============================] - 4s 916ms/step - loss: 4.8442 - acc: 0.5660 - val_loss: 5.5345 - val_acc: 0.5330
# Epoch 35/200
# 3/3 [==============================] - 4s 973ms/step - loss: 4.9761 - acc: 0.5686 - val_loss: 5.4571 - val_acc: 0.5375
# Epoch 36/200
# 3/3 [==============================] - 4s 1s/step - loss: 4.8131 - acc: 0.5743 - val_loss: 5.4086 - val_acc: 0.5366
# Epoch 37/200
# 3/3 [==============================] - 4s 985ms/step - loss: 4.6216 - acc: 0.5876 - val_loss: 5.3394 - val_acc: 0.5433
# Epoch 38/200
# 3/3 [==============================] - 3s 860ms/step - loss: 4.4559 - acc: 0.5877 - val_loss: 5.3474 - val_acc: 0.5509
# Epoch 39/200
# 3/3 [==============================] - 4s 1s/step - loss: 4.5572 - acc: 0.5987 - val_loss: 5.2559 - val_acc: 0.5464
# Epoch 40/200
# 3/3 [==============================] - 3s 921ms/step - loss: 4.4599 - acc: 0.6077 - val_loss: 5.2369 - val_acc: 0.5549
# Epoch 41/200
# 3/3 [==============================] - 3s 965ms/step - loss: 4.3473 - acc: 0.6004 - val_loss: 5.1907 - val_acc: 0.5596
# Epoch 42/200
# 3/3 [==============================] - 4s 1s/step - loss: 4.2366 - acc: 0.6157 - val_loss: 5.1319 - val_acc: 0.5527
# Epoch 43/200
# 3/3 [==============================] - 3s 860ms/step - loss: 4.1366 - acc: 0.6187 - val_loss: 5.0755 - val_acc: 0.5606
# Epoch 44/200
# 3/3 [==============================] - 3s 851ms/step - loss: 4.0784 - acc: 0.6263 - val_loss: 5.0325 - val_acc: 0.5603
# Epoch 45/200
# 3/3 [==============================] - 4s 975ms/step - loss: 4.0838 - acc: 0.6192 - val_loss: 5.0500 - val_acc: 0.5679
# Epoch 46/200
# 3/3 [==============================] - 3s 939ms/step - loss: 3.9177 - acc: 0.6262 - val_loss: 4.9378 - val_acc: 0.5753
# Epoch 47/200
# 3/3 [==============================] - 4s 985ms/step - loss: 3.8949 - acc: 0.6414 - val_loss: 4.9162 - val_acc: 0.5777
# Epoch 48/200
# 3/3 [==============================] - 4s 1s/step - loss: 3.7862 - acc: 0.6375 - val_loss: 4.8993 - val_acc: 0.5775
# Epoch 49/200
# 3/3 [==============================] - 3s 974ms/step - loss: 3.9045 - acc: 0.6406 - val_loss: 4.9290 - val_acc: 0.5752
# Epoch 50/200
# 3/3 [==============================] - 4s 980ms/step - loss: 3.7025 - acc: 0.6433 - val_loss: 4.8697 - val_acc: 0.5769
# Epoch 51/200
# 3/3 [==============================] - 3s 868ms/step - loss: 3.5697 - acc: 0.6612 - val_loss: 4.8126 - val_acc: 0.5796
# Epoch 52/200
# 3/3 [==============================] - 3s 941ms/step - loss: 3.6305 - acc: 0.6548 - val_loss: 4.8351 - val_acc: 0.5846
# Epoch 53/200
# 3/3 [==============================] - 4s 1s/step - loss: 3.5896 - acc: 0.6633 - val_loss: 4.7431 - val_acc: 0.5863
# Epoch 54/200
# 3/3 [==============================] - 4s 862ms/step - loss: 3.3530 - acc: 0.6683 - val_loss: 4.8067 - val_acc: 0.5856
# Epoch 55/200
# 3/3 [==============================] - 3s 986ms/step - loss: 3.2967 - acc: 0.6716 - val_loss: 4.7283 - val_acc: 0.5920
# Epoch 56/200
# 3/3 [==============================] - 3s 977ms/step - loss: 3.4833 - acc: 0.6683 - val_loss: 4.7178 - val_acc: 0.5886
# Epoch 57/200
# 3/3 [==============================] - 4s 1s/step - loss: 3.3420 - acc: 0.6776 - val_loss: 4.6886 - val_acc: 0.5908
# Epoch 58/200
# 3/3 [==============================] - 3s 877ms/step - loss: 3.2510 - acc: 0.6877 - val_loss: 4.6654 - val_acc: 0.5938
# Epoch 59/200
# 3/3 [==============================] - 3s 987ms/step - loss: 3.1913 - acc: 0.6768 - val_loss: 4.6422 - val_acc: 0.5943
# Epoch 60/200
# 3/3 [==============================] - 3s 856ms/step - loss: 3.1678 - acc: 0.6844 - val_loss: 4.6113 - val_acc: 0.6037
# Epoch 61/200
# 3/3 [==============================] - 3s 976ms/step - loss: 3.1348 - acc: 0.6897 - val_loss: 4.6720 - val_acc: 0.5981
# Epoch 62/200
# 3/3 [==============================] - 3s 976ms/step - loss: 3.0599 - acc: 0.6993 - val_loss: 4.5625 - val_acc: 0.6060
# Epoch 63/200
# 3/3 [==============================] - 3s 869ms/step - loss: 3.0189 - acc: 0.6973 - val_loss: 4.5948 - val_acc: 0.6121
# Epoch 64/200
# 3/3 [==============================] - 4s 1s/step - loss: 2.9325 - acc: 0.7020 - val_loss: 4.5291 - val_acc: 0.6147
# Epoch 65/200
# 3/3 [==============================] - 4s 868ms/step - loss: 3.0793 - acc: 0.6953 - val_loss: 4.5476 - val_acc: 0.6112
# Epoch 66/200
# 3/3 [==============================] - 3s 874ms/step - loss: 2.8098 - acc: 0.7102 - val_loss: 4.5541 - val_acc: 0.6087
# Epoch 67/200
# 3/3 [==============================] - 3s 904ms/step - loss: 2.7791 - acc: 0.7122 - val_loss: 4.5059 - val_acc: 0.6182
# Epoch 68/200
# 3/3 [==============================] - 4s 1s/step - loss: 2.7938 - acc: 0.7149 - val_loss: 4.5799 - val_acc: 0.6130
# Epoch 69/200
# 3/3 [==============================] - 4s 985ms/step - loss: 2.6925 - acc: 0.7136 - val_loss: 4.5600 - val_acc: 0.6175
# Epoch 70/200
# 3/3 [==============================] - 4s 975ms/step - loss: 2.8374 - acc: 0.7138 - val_loss: 4.5014 - val_acc: 0.6169
# Epoch 71/200
# 3/3 [==============================] - 5s 1s/step - loss: 2.7489 - acc: 0.7205 - val_loss: 4.5524 - val_acc: 0.6117
# Epoch 72/200
# 3/3 [==============================] - 3s 857ms/step - loss: 2.6627 - acc: 0.7284 - val_loss: 4.5206 - val_acc: 0.6169
# Epoch 73/200
# 3/3 [==============================] - 3s 870ms/step - loss: 2.6539 - acc: 0.7289 - val_loss: 4.5128 - val_acc: 0.6183
# Epoch 74/200
# 3/3 [==============================] - 3s 963ms/step - loss: 2.6769 - acc: 0.7347 - val_loss: 4.4698 - val_acc: 0.6221
# Epoch 75/200
# 3/3 [==============================] - 3s 869ms/step - loss: 2.5937 - acc: 0.7335 - val_loss: 4.4440 - val_acc: 0.6199
# Epoch 76/200
# 3/3 [==============================] - 3s 866ms/step - loss: 2.4886 - acc: 0.7381 - val_loss: 4.5101 - val_acc: 0.6274
# Epoch 77/200
# 3/3 [==============================] - 4s 1s/step - loss: 2.5242 - acc: 0.7365 - val_loss: 4.4516 - val_acc: 0.6212
# Epoch 78/200
# 3/3 [==============================] - 3s 906ms/step - loss: 2.5126 - acc: 0.7433 - val_loss: 4.4799 - val_acc: 0.6290
# Epoch 79/200
# 3/3 [==============================] - 3s 869ms/step - loss: 2.4634 - acc: 0.7406 - val_loss: 4.4540 - val_acc: 0.6280
# Epoch 80/200
# 3/3 [==============================] - 4s 1s/step - loss: 2.4425 - acc: 0.7397 - val_loss: 4.3948 - val_acc: 0.6391
# Epoch 81/200
# 3/3 [==============================] - 3s 868ms/step - loss: 2.3472 - acc: 0.7467 - val_loss: 4.4419 - val_acc: 0.6338
# Epoch 82/200
# 3/3 [==============================] - 3s 968ms/step - loss: 2.3408 - acc: 0.7545 - val_loss: 4.3773 - val_acc: 0.6355
# Epoch 83/200
# 3/3 [==============================] - 4s 1s/step - loss: 2.2484 - acc: 0.7677 - val_loss: 4.3818 - val_acc: 0.6418
# Epoch 84/200
# 3/3 [==============================] - 3s 856ms/step - loss: 2.2618 - acc: 0.7596 - val_loss: 4.3645 - val_acc: 0.6369
# Epoch 85/200
# 3/3 [==============================] - 3s 862ms/step - loss: 2.3127 - acc: 0.7645 - val_loss: 4.4137 - val_acc: 0.6354
# Epoch 86/200
# 3/3 [==============================] - 4s 1s/step - loss: 2.3670 - acc: 0.7567 - val_loss: 4.3679 - val_acc: 0.6449
# Epoch 87/200
# 3/3 [==============================] - 3s 853ms/step - loss: 2.2340 - acc: 0.7598 - val_loss: 4.3655 - val_acc: 0.6415
# Epoch 88/200
# 3/3 [==============================] - 3s 979ms/step - loss: 2.1970 - acc: 0.7680 - val_loss: 4.3469 - val_acc: 0.6439
# Epoch 89/200
# 3/3 [==============================] - 4s 1s/step - loss: 2.1849 - acc: 0.7668 - val_loss: 4.3880 - val_acc: 0.6391
# Epoch 90/200
# 3/3 [==============================] - 4s 1s/step - loss: 2.1064 - acc: 0.7685 - val_loss: 4.3978 - val_acc: 0.6445
# Epoch 91/200
# 3/3 [==============================] - 3s 987ms/step - loss: 2.0944 - acc: 0.7707 - val_loss: 4.4012 - val_acc: 0.6499
# Epoch 92/200
# 3/3 [==============================] - 4s 1s/step - loss: 2.1037 - acc: 0.7699 - val_loss: 4.4180 - val_acc: 0.6398
# Epoch 93/200
# 3/3 [==============================] - 3s 881ms/step - loss: 2.1119 - acc: 0.7726 - val_loss: 4.4152 - val_acc: 0.6433
# Epoch 94/200
# 3/3 [==============================] - 3s 873ms/step - loss: 2.0336 - acc: 0.7758 - val_loss: 4.3890 - val_acc: 0.6409
# Epoch 95/200
# 3/3 [==============================] - 4s 878ms/step - loss: 1.9385 - acc: 0.7787 - val_loss: 4.4037 - val_acc: 0.6446
# Epoch 96/200
# 3/3 [==============================] - 3s 975ms/step - loss: 2.0583 - acc: 0.7779 - val_loss: 4.3782 - val_acc: 0.6535
# Epoch 97/200
# 3/3 [==============================] - 4s 1s/step - loss: 1.9363 - acc: 0.7865 - val_loss: 4.4091 - val_acc: 0.6444
# Epoch 98/200
# 3/3 [==============================] - 4s 983ms/step - loss: 1.9709 - acc: 0.7847 - val_loss: 4.3509 - val_acc: 0.6466
# Epoch 99/200
# 3/3 [==============================] - 3s 974ms/step - loss: 1.9316 - acc: 0.7931 - val_loss: 4.3889 - val_acc: 0.6426
# Epoch 100/200
# 3/3 [==============================] - 3s 855ms/step - loss: 1.9904 - acc: 0.7841 - val_loss: 4.3569 - val_acc: 0.6478
# Epoch 101/200
# 3/3 [==============================] - 4s 1s/step - loss: 1.8211 - acc: 0.7940 - val_loss: 4.4118 - val_acc: 0.6397
# Epoch 102/200
# 3/3 [==============================] - 3s 880ms/step - loss: 1.8626 - acc: 0.7912 - val_loss: 4.3886 - val_acc: 0.6408
# Epoch 103/200
# 3/3 [==============================] - 3s 863ms/step - loss: 1.8231 - acc: 0.7916 - val_loss: 4.3713 - val_acc: 0.6454
# Epoch 104/200
# 3/3 [==============================] - 4s 1s/step - loss: 1.7997 - acc: 0.7950 - val_loss: 4.3573 - val_acc: 0.6484
# Epoch 105/200
# 3/3 [==============================] - 4s 972ms/step - loss: 1.7854 - acc: 0.8028 - val_loss: 4.3440 - val_acc: 0.6542
# Epoch 106/200
# 3/3 [==============================] - 3s 972ms/step - loss: 1.7650 - acc: 0.7951 - val_loss: 4.3495 - val_acc: 0.6506
# Epoch 107/200
# 3/3 [==============================] - 4s 860ms/step - loss: 1.7602 - acc: 0.7946 - val_loss: 4.3782 - val_acc: 0.6544
# Epoch 108/200
# 3/3 [==============================] - 3s 865ms/step - loss: 1.7094 - acc: 0.7962 - val_loss: 4.4008 - val_acc: 0.6467
# Epoch 109/200
# 3/3 [==============================] - 3s 980ms/step - loss: 1.7252 - acc: 0.8012 - val_loss: 4.4270 - val_acc: 0.6446
# Epoch 110/200
# 3/3 [==============================] - 4s 1s/step - loss: 1.7272 - acc: 0.8035 - val_loss: 4.4140 - val_acc: 0.6479
# Epoch 111/200
# 3/3 [==============================] - 3s 868ms/step - loss: 1.7094 - acc: 0.8124 - val_loss: 4.4116 - val_acc: 0.6553
# Epoch 112/200
# 3/3 [==============================] - 3s 892ms/step - loss: 1.7284 - acc: 0.8049 - val_loss: 4.4016 - val_acc: 0.6478
# Epoch 113/200
# 3/3 [==============================] - 3s 952ms/step - loss: 1.6528 - acc: 0.8052 - val_loss: 4.4291 - val_acc: 0.6513
# Epoch 114/200
# 3/3 [==============================] - 4s 1s/step - loss: 1.6346 - acc: 0.8119 - val_loss: 4.4436 - val_acc: 0.6524
# Epoch 115/200
# 3/3 [==============================] - 3s 983ms/step - loss: 1.5791 - acc: 0.8077 - val_loss: 4.4407 - val_acc: 0.6458
# Epoch 116/200
# 3/3 [==============================] - 4s 1s/step - loss: 1.5616 - acc: 0.8179 - val_loss: 4.4273 - val_acc: 0.6464
# Epoch 117/200
# 3/3 [==============================] - 3s 876ms/step - loss: 1.6028 - acc: 0.8180 - val_loss: 4.4190 - val_acc: 0.6460
# Epoch 118/200
# 3/3 [==============================] - 3s 862ms/step - loss: 1.5286 - acc: 0.8215 - val_loss: 4.3967 - val_acc: 0.6540
# Epoch 119/200
# 3/3 [==============================] - 4s 1s/step - loss: 1.5483 - acc: 0.8267 - val_loss: 4.3670 - val_acc: 0.6443
# Epoch 120/200
# 3/3 [==============================] - 4s 855ms/step - loss: 1.5671 - acc: 0.8166 - val_loss: 4.4215 - val_acc: 0.6541
# Epoch 121/200
# 3/3 [==============================] - 3s 863ms/step - loss: 1.5843 - acc: 0.8184 - val_loss: 4.4367 - val_acc: 0.6481
# Epoch 122/200
# 3/3 [==============================] - 3s 948ms/step - loss: 1.5146 - acc: 0.8305 - val_loss: 4.4122 - val_acc: 0.6563
# Epoch 123/200
# 3/3 [==============================] - 4s 872ms/step - loss: 1.4713 - acc: 0.8274 - val_loss: 4.4405 - val_acc: 0.6529
# Epoch 124/200
# 3/3 [==============================] - 3s 877ms/step - loss: 1.5886 - acc: 0.8174 - val_loss: 4.4181 - val_acc: 0.6552
# Epoch 125/200
# 3/3 [==============================] - 3s 992ms/step - loss: 1.5043 - acc: 0.8326 - val_loss: 4.4166 - val_acc: 0.6510
# Epoch 126/200
# 3/3 [==============================] - 4s 996ms/step - loss: 1.4583 - acc: 0.8360 - val_loss: 4.4287 - val_acc: 0.6530
# Epoch 127/200
# 3/3 [==============================] - 3s 981ms/step - loss: 1.4645 - acc: 0.8229 - val_loss: 4.4260 - val_acc: 0.6581
# Epoch 128/200
# 3/3 [==============================] - 4s 1s/step - loss: 1.4693 - acc: 0.8291 - val_loss: 4.3771 - val_acc: 0.6566
# Epoch 129/200
# 3/3 [==============================] - 4s 973ms/step - loss: 1.3935 - acc: 0.8285 - val_loss: 4.4050 - val_acc: 0.6615
# Epoch 130/200
# 3/3 [==============================] - 3s 880ms/step - loss: 1.4382 - acc: 0.8274 - val_loss: 4.4034 - val_acc: 0.6528
# Epoch 131/200
# 3/3 [==============================] - 4s 1s/step - loss: 1.3812 - acc: 0.8340 - val_loss: 4.4140 - val_acc: 0.6547
# Epoch 132/200
# 3/3 [==============================] - 3s 973ms/step - loss: 1.4236 - acc: 0.8314 - val_loss: 4.4345 - val_acc: 0.6589
# Epoch 133/200
# 3/3 [==============================] - 3s 890ms/step - loss: 1.3617 - acc: 0.8325 - val_loss: 4.4491 - val_acc: 0.6572
# Epoch 134/200
# 3/3 [==============================] - 4s 1s/step - loss: 1.4290 - acc: 0.8308 - val_loss: 4.4444 - val_acc: 0.6528
# Epoch 135/200
# 3/3 [==============================] - 3s 883ms/step - loss: 1.4219 - acc: 0.8304 - val_loss: 4.4675 - val_acc: 0.6595
# Epoch 136/200
# 3/3 [==============================] - 3s 977ms/step - loss: 1.3477 - acc: 0.8282 - val_loss: 4.4874 - val_acc: 0.6574
# Epoch 137/200
# 3/3 [==============================] - 4s 870ms/step - loss: 1.3125 - acc: 0.8404 - val_loss: 4.4442 - val_acc: 0.6562
# Epoch 138/200
# 3/3 [==============================] - 4s 1s/step - loss: 1.3488 - acc: 0.8419 - val_loss: 4.4975 - val_acc: 0.6614
# Epoch 139/200
# 3/3 [==============================] - 4s 1s/step - loss: 1.2786 - acc: 0.8381 - val_loss: 4.5418 - val_acc: 0.6548
# Epoch 140/200
# 3/3 [==============================] - 4s 986ms/step - loss: 1.3293 - acc: 0.8374 - val_loss: 4.5434 - val_acc: 0.6529
# Epoch 141/200
# 3/3 [==============================] - 3s 864ms/step - loss: 1.2514 - acc: 0.8412 - val_loss: 4.5134 - val_acc: 0.6584
# Epoch 142/200
# 3/3 [==============================] - 4s 1s/step - loss: 1.2707 - acc: 0.8457 - val_loss: 4.4883 - val_acc: 0.6585
# Epoch 143/200
# 3/3 [==============================] - 3s 864ms/step - loss: 1.3106 - acc: 0.8462 - val_loss: 4.5395 - val_acc: 0.6570
# Epoch 144/200
# 3/3 [==============================] - 4s 1s/step - loss: 1.2769 - acc: 0.8391 - val_loss: 4.4618 - val_acc: 0.6643
# Epoch 145/200
# 3/3 [==============================] - 3s 869ms/step - loss: 1.2920 - acc: 0.8422 - val_loss: 4.4892 - val_acc: 0.6545
# Epoch 146/200
# 3/3 [==============================] - 3s 868ms/step - loss: 1.2607 - acc: 0.8432 - val_loss: 4.4964 - val_acc: 0.6490
# Epoch 147/200
# 3/3 [==============================] - 3s 876ms/step - loss: 1.2559 - acc: 0.8498 - val_loss: 4.4822 - val_acc: 0.6588
# Epoch 148/200
# 3/3 [==============================] - 3s 873ms/step - loss: 1.2487 - acc: 0.8456 - val_loss: 4.4961 - val_acc: 0.6555
# Epoch 149/200
# 3/3 [==============================] - 3s 864ms/step - loss: 1.1598 - acc: 0.8515 - val_loss: 4.5532 - val_acc: 0.6631
# Epoch 150/200
# 3/3 [==============================] - 4s 1s/step - loss: 1.1864 - acc: 0.8507 - val_loss: 4.5566 - val_acc: 0.6556
# Epoch 151/200
# 3/3 [==============================] - 3s 875ms/step - loss: 1.1761 - acc: 0.8562 - val_loss: 4.5750 - val_acc: 0.6685
# Epoch 152/200
# 3/3 [==============================] - 3s 873ms/step - loss: 1.2090 - acc: 0.8554 - val_loss: 4.5774 - val_acc: 0.6579
# Epoch 153/200
# 3/3 [==============================] - 4s 986ms/step - loss: 1.1678 - acc: 0.8544 - val_loss: 4.5967 - val_acc: 0.6593
# Epoch 154/200
# 3/3 [==============================] - 3s 869ms/step - loss: 1.1691 - acc: 0.8537 - val_loss: 4.6150 - val_acc: 0.6551
# Epoch 155/200
# 3/3 [==============================] - 4s 972ms/step - loss: 1.1632 - acc: 0.8564 - val_loss: 4.5744 - val_acc: 0.6606
# Epoch 156/200
# 3/3 [==============================] - 4s 983ms/step - loss: 1.1619 - acc: 0.8561 - val_loss: 4.6011 - val_acc: 0.6596
# Epoch 157/200
# 3/3 [==============================] - 3s 983ms/step - loss: 1.1300 - acc: 0.8542 - val_loss: 4.6175 - val_acc: 0.6641
# Epoch 158/200
# 3/3 [==============================] - 3s 969ms/step - loss: 1.1424 - acc: 0.8519 - val_loss: 4.6442 - val_acc: 0.6660
# Epoch 159/200
# 3/3 [==============================] - 3s 981ms/step - loss: 1.0805 - acc: 0.8610 - val_loss: 4.6080 - val_acc: 0.6633
# Epoch 160/200
# 3/3 [==============================] - 3s 865ms/step - loss: 1.0966 - acc: 0.8619 - val_loss: 4.6000 - val_acc: 0.6599
# Epoch 161/200
# 3/3 [==============================] - 4s 1s/step - loss: 1.0775 - acc: 0.8602 - val_loss: 4.6777 - val_acc: 0.6520
# Epoch 162/200
# 3/3 [==============================] - 3s 860ms/step - loss: 1.1235 - acc: 0.8621 - val_loss: 4.6696 - val_acc: 0.6625
# Epoch 163/200
# 3/3 [==============================] - 3s 975ms/step - loss: 1.1059 - acc: 0.8623 - val_loss: 4.6718 - val_acc: 0.6516
# Epoch 164/200
# 3/3 [==============================] - 4s 1s/step - loss: 1.1154 - acc: 0.8590 - val_loss: 4.7001 - val_acc: 0.6593
# Epoch 165/200
# 3/3 [==============================] - 3s 983ms/step - loss: 1.0800 - acc: 0.8596 - val_loss: 4.6285 - val_acc: 0.6617
# Epoch 166/200
# 3/3 [==============================] - 4s 1s/step - loss: 1.0949 - acc: 0.8605 - val_loss: 4.6472 - val_acc: 0.6621
# Epoch 167/200
# 3/3 [==============================] - 4s 924ms/step - loss: 1.0785 - acc: 0.8609 - val_loss: 4.6909 - val_acc: 0.6483
# Epoch 168/200
# 3/3 [==============================] - 3s 856ms/step - loss: 1.0442 - acc: 0.8647 - val_loss: 4.6555 - val_acc: 0.6625
# Epoch 169/200
# 3/3 [==============================] - 3s 975ms/step - loss: 1.0446 - acc: 0.8669 - val_loss: 4.6382 - val_acc: 0.6586
# Epoch 170/200
# 3/3 [==============================] - 4s 1s/step - loss: 1.0238 - acc: 0.8714 - val_loss: 4.6497 - val_acc: 0.6660
# Epoch 171/200
# 3/3 [==============================] - 3s 861ms/step - loss: 1.0301 - acc: 0.8656 - val_loss: 4.6845 - val_acc: 0.6596
# Epoch 172/200
# 3/3 [==============================] - 3s 987ms/step - loss: 1.0743 - acc: 0.8644 - val_loss: 4.6433 - val_acc: 0.6598
# Epoch 173/200
# 3/3 [==============================] - 4s 1s/step - loss: 1.0312 - acc: 0.8692 - val_loss: 4.6132 - val_acc: 0.6662
# Epoch 174/200
# 3/3 [==============================] - 3s 863ms/step - loss: 0.9905 - acc: 0.8701 - val_loss: 4.6929 - val_acc: 0.6560
# Epoch 175/200
# 3/3 [==============================] - 3s 980ms/step - loss: 0.9988 - acc: 0.8649 - val_loss: 4.6548 - val_acc: 0.6621
# Epoch 176/200
# 3/3 [==============================] - 4s 1s/step - loss: 0.9963 - acc: 0.8667 - val_loss: 4.6569 - val_acc: 0.6664
# Epoch 177/200
# 3/3 [==============================] - 4s 1s/step - loss: 0.9923 - acc: 0.8598 - val_loss: 4.6647 - val_acc: 0.6674
# Epoch 178/200
# 3/3 [==============================] - 3s 852ms/step - loss: 0.9864 - acc: 0.8657 - val_loss: 4.6938 - val_acc: 0.6658
# Epoch 179/200
# 3/3 [==============================] - 4s 1s/step - loss: 0.9993 - acc: 0.8708 - val_loss: 4.6527 - val_acc: 0.6652
# Epoch 180/200
# 3/3 [==============================] - 3s 976ms/step - loss: 1.0054 - acc: 0.8705 - val_loss: 4.7126 - val_acc: 0.6617
# Epoch 181/200
# 3/3 [==============================] - 3s 978ms/step - loss: 0.9567 - acc: 0.8710 - val_loss: 4.7229 - val_acc: 0.6643
# Epoch 182/200
# 3/3 [==============================] - 4s 984ms/step - loss: 0.9826 - acc: 0.8718 - val_loss: 4.7320 - val_acc: 0.6638
# Epoch 183/200
# 3/3 [==============================] - 3s 882ms/step - loss: 0.9832 - acc: 0.8673 - val_loss: 4.7661 - val_acc: 0.6612
# Epoch 184/200
# 3/3 [==============================] - 3s 970ms/step - loss: 0.9475 - acc: 0.8741 - val_loss: 4.7635 - val_acc: 0.6637
# Epoch 185/200
# 3/3 [==============================] - 4s 930ms/step - loss: 0.9846 - acc: 0.8731 - val_loss: 4.7570 - val_acc: 0.6679
# Epoch 186/200
# 3/3 [==============================] - 3s 974ms/step - loss: 0.9765 - acc: 0.8708 - val_loss: 4.7992 - val_acc: 0.6580
# Epoch 187/200
# 3/3 [==============================] - 3s 974ms/step - loss: 0.9556 - acc: 0.8768 - val_loss: 4.7283 - val_acc: 0.6632
# Epoch 188/200
# 3/3 [==============================] - 4s 1s/step - loss: 0.9797 - acc: 0.8705 - val_loss: 4.7047 - val_acc: 0.6656
# Epoch 189/200
# 3/3 [==============================] - 3s 871ms/step - loss: 0.9141 - acc: 0.8758 - val_loss: 4.7671 - val_acc: 0.6637
# Epoch 190/200
# 3/3 [==============================] - 3s 971ms/step - loss: 0.9134 - acc: 0.8774 - val_loss: 4.7800 - val_acc: 0.6685
# Epoch 191/200
# 3/3 [==============================] - 4s 1s/step - loss: 0.9536 - acc: 0.8754 - val_loss: 4.7570 - val_acc: 0.6645
# Epoch 192/200
# 3/3 [==============================] - 3s 975ms/step - loss: 0.9106 - acc: 0.8795 - val_loss: 4.8251 - val_acc: 0.6605
# Epoch 193/200
# 3/3 [==============================] - 3s 966ms/step - loss: 0.9307 - acc: 0.8748 - val_loss: 4.8161 - val_acc: 0.6679
# Epoch 194/200
# 3/3 [==============================] - 4s 871ms/step - loss: 0.9261 - acc: 0.8753 - val_loss: 4.7910 - val_acc: 0.6632
# Epoch 195/200
# 3/3 [==============================] - 3s 982ms/step - loss: 0.8888 - acc: 0.8826 - val_loss: 4.8528 - val_acc: 0.6675
# Epoch 196/200
# 3/3 [==============================] - 4s 1s/step - loss: 0.9146 - acc: 0.8773 - val_loss: 4.8114 - val_acc: 0.6591
# Epoch 197/200
# 3/3 [==============================] - 4s 856ms/step - loss: 0.9281 - acc: 0.8766 - val_loss: 4.7914 - val_acc: 0.6695
# Epoch 198/200
# 3/3 [==============================] - 3s 857ms/step - loss: 0.9028 - acc: 0.8788 - val_loss: 4.7616 - val_acc: 0.6714
# Epoch 199/200
# 3/3 [==============================] - 4s 1s/step - loss: 0.9147 - acc: 0.8750 - val_loss: 4.8153 - val_acc: 0.6687
# Epoch 200/200
# 3/3 [==============================] - 3s 857ms/step - loss: 0.9090 - acc: 0.8797 - val_loss: 4.8156 - val_acc: 0.6727

# %% [markdown]
# ## Check sample predictions

# %%
vocab = vectorization.get_vocabulary()
index_lookup = dict(zip(range(len(vocab)), vocab))
max_decoded_sentence_length = SEQ_LENGTH - 1
valid_images = list(valid_data.keys())


def generate_caption():
    # Select a random image from the validation dataset
    sample_img = np.random.choice(valid_images)

    # Read the image from the disk
    sample_img = decode_and_resize(sample_img)
    img = sample_img.numpy().clip(0, 255).astype(np.uint8)
    plt.imshow(img)
    plt.show()

    # Pass the image to the CNN
    img = tf.expand_dims(sample_img, 0)
    img = caption_model.cnn_model(img)

    # Pass the image features to the Transformer encoder
    encoded_img = caption_model.encoder(img, training=False)

    # Generate the caption using the Transformer decoder
    decoded_caption = "<start> "
    for i in range(max_decoded_sentence_length):
        tokenized_caption = vectorization([decoded_caption])[:, :-1]
        mask = tf.math.not_equal(tokenized_caption, 0)
        predictions = caption_model.decoder(
            tokenized_caption, encoded_img, training=False, mask=mask
        )
        sampled_token_index = np.argmax(predictions[0, i, :])
        sampled_token = index_lookup[sampled_token_index]
        if sampled_token == " <end>":
            break
        decoded_caption += " " + sampled_token

    decoded_caption = decoded_caption.replace("<start> ", "")
    decoded_caption = decoded_caption.replace(" <end>", "").strip()
    print("Predicted Caption: ", decoded_caption)


# Check predictions for a few samples
generate_caption()
generate_caption()
generate_caption()
generate_caption()
# Out:
# Predicted Caption:  vehículo cruza de carril e impacta sobre otro vehículo que se encontraba transitando por él otro
# Predicted Caption:  vehículo a y vehículo a impactan por una plaza de sentido giratorio a mientras que circulaba por una plaza de sentido giratorio mientras que vehículo a
# Predicted Caption:  vehículo a venía de la derecha en una entrada mientras que vehículo b impactó al vehículo b en lateral izquierdo mientras que vehículo b
# Predicted Caption:  vehículo a es impactado por vehículo b cuando este último hace un cambio de carril y lo impacta mientras que venia circulando

# %% [markdown]
# ## End Notes
#
# We saw that the model starts to generate reasonable captions after a few epochs. To keep
# this example easily runnable, we have trained it with a few constraints, like a minimal
# number of attention heads. To improve the predictions, you can try changing these training
# settings and find a good model for your use case.
