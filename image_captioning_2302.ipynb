# %% [markdown]
# <a href="https://colab.research.google.com/github/etoro2306/capstone_project/blob/dev/image_captioning_2302.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Image Captioning
#
# **Author:** [A_K_Nain](https://twitter.com/A_K_Nain)<br>
# **Date created:** 2021/05/29<br>
# **Last modified:** 2021/10/31<br>
# **Description:** Implement an image captioning model using a CNN and a Transformer.

# %% [markdown]
# ## Setup

# %%
import os
import re
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.applications import efficientnet
from tensorflow.keras.layers import TextVectorization


seed = 100
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# ## Download the dataset
#
# We will be using the Flickr8K dataset for this tutorial. This dataset comprises over
# 8,000 images, that are each paired with five different captions.

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# Path to the images
IMAGES_PATH = "/content/drive/MyDrive/Capstone Project/Project/cropped.capstone/cropped"

# Desired image dimensions
IMAGE_SIZE = (299, 505)

# Vocabulary size
VOCAB_SIZE = 10000

# Fixed length allowed for any sequence
SEQ_LENGTH = 30

# Dimension for the image embeddings and token embeddings
EMBED_DIM = 512

# Per-layer units in the feed-forward network
FF_DIM = 512

# Other training parameters
BATCH_SIZE = 64
EPOCHS = 300
AUTOTUNE = tf.data.AUTOTUNE

# %% [markdown]
# ## Preparing the dataset

# %%
def load_captions_data(filename):
    """Loads captions (text) data and maps them to corresponding images.

    Args:
        filename: Path to the text file containing caption data.

    Returns:
        caption_mapping: Dictionary mapping image names and the corresponding captions
        text_data: List containing all the available captions
    """

    with open(filename, encoding = "latin-1") as caption_file:
        caption_data = caption_file.readlines()
        caption_mapping = {}
        text_data = []
        images_to_skip = set()

        for line in caption_data:
            line = line.rstrip("\n")
            # Image name and captions are separated using a tab
            img_name, caption = line.split("\t")

            # Each image is repeated five times for the five different captions.
            # Each image name has a suffix `#(caption_number)`
            img_name = img_name.split("#")[0]
            img_name = os.path.join(IMAGES_PATH, img_name.strip())

            # We will remove caption that are either too short to too long
            tokens = caption.strip().split()

            if len(tokens) < 5 or len(tokens) > SEQ_LENGTH:
                images_to_skip.add(img_name)
                continue

            if img_name.endswith("jpg") and img_name not in images_to_skip:
                # We will add a start and an end token to each caption
                caption = "<start> " + caption.strip() + " <end>"
                text_data.append(caption)

                if img_name in caption_mapping:
                    caption_mapping[img_name].append(caption)
                else:
                    caption_mapping[img_name] = [caption]

        for img_name in images_to_skip:
            if img_name in caption_mapping:
                del caption_mapping[img_name]

        return caption_mapping, text_data


def train_val_split(caption_data, train_size=0.8, shuffle=True):
    """Split the captioning dataset into train and validation sets.

    Args:
        caption_data (dict): Dictionary containing the mapped caption data
        train_size (float): Fraction of all the full dataset to use as training data
        shuffle (bool): Whether to shuffle the dataset before splitting

    Returns:
        Traning and validation datasets as two separated dicts
    """

    # 1. Get the list of all image names
    all_images = list(caption_data.keys())

    # 2. Shuffle if necessary
    if shuffle:
        np.random.shuffle(all_images)

    # 3. Split into training and validation sets
    train_size = int(len(caption_data) * train_size)

    training_data = {
        img_name: caption_data[img_name] for img_name in all_images[:train_size]
    }
    validation_data = {
        img_name: caption_data[img_name] for img_name in all_images[train_size:]
    }

    # 4. Return the splits
    return training_data, validation_data


# Load the dataset
captions_mapping, text_data = load_captions_data("/content/drive/MyDrive/Capstone Project/Project/captions.capstone/captions20.02.txt")

# Split the dataset into training and validation sets
train_data, valid_data = train_val_split(captions_mapping)
print("Number of training samples: ", len(train_data))
print("Number of validation samples: ", len(valid_data))
# Out:
# Number of training samples:  143
# Number of validation samples:  36

# %% [markdown]
# ## Vectorizing the text data
#
# We'll use the `TextVectorization` layer to vectorize the text data,
# that is to say, to turn the
# original strings into integer sequences where each integer represents the index of
# a word in a vocabulary. We will use a custom string standardization scheme
# (strip punctuation characters except `<` and `>`) and the default
# splitting scheme (split on whitespace).

# %%
def custom_standardization(input_string):
    lowercase = tf.strings.lower(input_string)
    return tf.strings.regex_replace(lowercase, "[%s]" % re.escape(strip_chars), "")


strip_chars = "!\"#$%&'()*+,-./:;<=>?@[\]^_`{|}~"
strip_chars = strip_chars.replace("<", "")
strip_chars = strip_chars.replace(">", "")

vectorization = TextVectorization(
    max_tokens=VOCAB_SIZE,
    output_mode="int",
    output_sequence_length=SEQ_LENGTH,
    standardize=custom_standardization,
)
vectorization.adapt(text_data)

# Data augmentation for image data
image_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.2),
        layers.RandomContrast(0.3),
    ]
)

# %% [markdown]
# ## Building a `tf.data.Dataset` pipeline for training
#
# We will generate pairs of images and corresponding captions using a `tf.data.Dataset` object.
# The pipeline consists of two steps:
#
# 1. Read the image from the disk
# 2. Tokenize all the five captions corresponding to the image

# %%
def decode_and_resize(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, IMAGE_SIZE)
    img = tf.image.convert_image_dtype(img, tf.float32)
    return img


def process_input(img_path, captions):
    return decode_and_resize(img_path), vectorization(captions)


def make_dataset(images, captions):
    dataset = tf.data.Dataset.from_tensor_slices((images, captions))
    dataset = dataset.shuffle(BATCH_SIZE * 8)
    dataset = dataset.map(process_input, num_parallel_calls=AUTOTUNE)
    dataset = dataset.batch(BATCH_SIZE).prefetch(AUTOTUNE)

    return dataset


# Pass the list of images and the list of corresponding captions
train_dataset = make_dataset(list(train_data.keys()), list(train_data.values()))

valid_dataset = make_dataset(list(valid_data.keys()), list(valid_data.values()))

# %% [markdown]
# ## Building the model
#
# Our image captioning architecture consists of three models:
#
# 1. A CNN: used to extract the image features
# 2. A TransformerEncoder: The extracted image features are then passed to a Transformer
#                     based encoder that generates a new representation of the inputs
# 3. A TransformerDecoder: This model takes the encoder output and the text data
#                     (sequences) as inputs and tries to learn to generate the caption.

# %%
def get_cnn_model():
    base_model = efficientnet.EfficientNetB0(
        input_shape=(*IMAGE_SIZE, 3), include_top=False, weights="imagenet",
    )
    # We freeze our feature extractor
    base_model.trainable = False
    base_model_out = base_model.output
    base_model_out = layers.Reshape((-1, base_model_out.shape[-1]))(base_model_out)
    cnn_model = keras.models.Model(base_model.input, base_model_out)
    return cnn_model


class TransformerEncoderBlock(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention_1 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.0
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.dense_1 = layers.Dense(embed_dim, activation="relu")

    def call(self, inputs, training, mask=None):
        inputs = self.layernorm_1(inputs)
        inputs = self.dense_1(inputs)

        attention_output_1 = self.attention_1(
            query=inputs,
            value=inputs,
            key=inputs,
            attention_mask=None,
            training=training,
        )
        out_1 = self.layernorm_2(inputs + attention_output_1)
        return out_1


class PositionalEmbedding(layers.Layer):
    def __init__(self, sequence_length, vocab_size, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.token_embeddings = layers.Embedding(
            input_dim=vocab_size, output_dim=embed_dim
        )
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=embed_dim
        )
        self.sequence_length = sequence_length
        self.vocab_size = vocab_size
        self.embed_dim = embed_dim
        self.embed_scale = tf.math.sqrt(tf.cast(embed_dim, tf.float32))

    def call(self, inputs):
        length = tf.shape(inputs)[-1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_tokens = self.token_embeddings(inputs)
        embedded_tokens = embedded_tokens * self.embed_scale
        embedded_positions = self.position_embeddings(positions)
        return embedded_tokens + embedded_positions

    def compute_mask(self, inputs, mask=None):
        return tf.math.not_equal(inputs, 0)


class TransformerDecoderBlock(layers.Layer):
    def __init__(self, embed_dim, ff_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.ff_dim = ff_dim
        self.num_heads = num_heads
        self.attention_1 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.1
        )
        self.attention_2 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.1
        )
        self.ffn_layer_1 = layers.Dense(ff_dim, activation="relu")
        self.ffn_layer_2 = layers.Dense(embed_dim)

        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.layernorm_3 = layers.LayerNormalization()

        self.embedding = PositionalEmbedding(
            embed_dim=EMBED_DIM, sequence_length=SEQ_LENGTH, vocab_size=VOCAB_SIZE
        )
        self.out = layers.Dense(VOCAB_SIZE, activation="softmax")

        self.dropout_1 = layers.Dropout(0.3)
        self.dropout_2 = layers.Dropout(0.5)
        self.supports_masking = True

    def call(self, inputs, encoder_outputs, training, mask=None):
        inputs = self.embedding(inputs)
        causal_mask = self.get_causal_attention_mask(inputs)

        if mask is not None:
            padding_mask = tf.cast(mask[:, :, tf.newaxis], dtype=tf.int32)
            combined_mask = tf.cast(mask[:, tf.newaxis, :], dtype=tf.int32)
            combined_mask = tf.minimum(combined_mask, causal_mask)

        attention_output_1 = self.attention_1(
            query=inputs,
            value=inputs,
            key=inputs,
            attention_mask=combined_mask,
            training=training,
        )
        out_1 = self.layernorm_1(inputs + attention_output_1)

        attention_output_2 = self.attention_2(
            query=out_1,
            value=encoder_outputs,
            key=encoder_outputs,
            attention_mask=padding_mask,
            training=training,
        )
        out_2 = self.layernorm_2(out_1 + attention_output_2)

        ffn_out = self.ffn_layer_1(out_2)
        ffn_out = self.dropout_1(ffn_out, training=training)
        ffn_out = self.ffn_layer_2(ffn_out)

        ffn_out = self.layernorm_3(ffn_out + out_2, training=training)
        ffn_out = self.dropout_2(ffn_out, training=training)
        preds = self.out(ffn_out)
        return preds

    def get_causal_attention_mask(self, inputs):
        input_shape = tf.shape(inputs)
        batch_size, sequence_length = input_shape[0], input_shape[1]
        i = tf.range(sequence_length)[:, tf.newaxis]
        j = tf.range(sequence_length)
        mask = tf.cast(i >= j, dtype="int32")
        mask = tf.reshape(mask, (1, input_shape[1], input_shape[1]))
        mult = tf.concat(
            [tf.expand_dims(batch_size, -1), tf.constant([1, 1], dtype=tf.int32)],
            axis=0,
        )
        return tf.tile(mask, mult)


class ImageCaptioningModel(keras.Model):
    def __init__(
        self, cnn_model, encoder, decoder, num_captions_per_image=3, image_aug=None,
    ):
        super().__init__()
        self.cnn_model = cnn_model
        self.encoder = encoder
        self.decoder = decoder
        self.loss_tracker = keras.metrics.Mean(name="loss")
        self.acc_tracker = keras.metrics.Mean(name="accuracy")
        self.num_captions_per_image = num_captions_per_image
        self.image_aug = image_aug

    def calculate_loss(self, y_true, y_pred, mask):
        loss = self.loss(y_true, y_pred)
        mask = tf.cast(mask, dtype=loss.dtype)
        loss *= mask
        return tf.reduce_sum(loss) / tf.reduce_sum(mask)

    def calculate_accuracy(self, y_true, y_pred, mask):
        accuracy = tf.equal(y_true, tf.argmax(y_pred, axis=2))
        accuracy = tf.math.logical_and(mask, accuracy)
        accuracy = tf.cast(accuracy, dtype=tf.float32)
        mask = tf.cast(mask, dtype=tf.float32)
        return tf.reduce_sum(accuracy) / tf.reduce_sum(mask)

    def _compute_caption_loss_and_acc(self, img_embed, batch_seq, training=True):
        encoder_out = self.encoder(img_embed, training=training)
        batch_seq_inp = batch_seq[:, :-1]
        batch_seq_true = batch_seq[:, 1:]
        mask = tf.math.not_equal(batch_seq_true, 0)
        batch_seq_pred = self.decoder(
            batch_seq_inp, encoder_out, training=training, mask=mask
        )
        loss = self.calculate_loss(batch_seq_true, batch_seq_pred, mask)
        acc = self.calculate_accuracy(batch_seq_true, batch_seq_pred, mask)
        return loss, acc

    def train_step(self, batch_data):
        batch_img, batch_seq = batch_data
        batch_loss = 0
        batch_acc = 0

        if self.image_aug:
            batch_img = self.image_aug(batch_img)

        # 1. Get image embeddings
        img_embed = self.cnn_model(batch_img)

        # 2. Pass each of the five captions one by one to the decoder
        # along with the encoder outputs and compute the loss as well as accuracy
        # for each caption.
        for i in range(self.num_captions_per_image):
            with tf.GradientTape() as tape:
                loss, acc = self._compute_caption_loss_and_acc(
                    img_embed, batch_seq[:, i, :], training=True
                )

                # 3. Update loss and accuracy
                batch_loss += loss
                batch_acc += acc

            # 4. Get the list of all the trainable weights
            train_vars = (
                self.encoder.trainable_variables + self.decoder.trainable_variables
            )

            # 5. Get the gradients
            grads = tape.gradient(loss, train_vars)

            # 6. Update the trainable weights
            self.optimizer.apply_gradients(zip(grads, train_vars))

        # 7. Update the trackers
        batch_acc /= float(self.num_captions_per_image)
        self.loss_tracker.update_state(batch_loss)
        self.acc_tracker.update_state(batch_acc)

        # 8. Return the loss and accuracy values
        return {"loss": self.loss_tracker.result(), "acc": self.acc_tracker.result()}

    def test_step(self, batch_data):
        batch_img, batch_seq = batch_data
        batch_loss = 0
        batch_acc = 0

        # 1. Get image embeddings
        img_embed = self.cnn_model(batch_img)

        # 2. Pass each of the five captions one by one to the decoder
        # along with the encoder outputs and compute the loss as well as accuracy
        # for each caption.
        for i in range(self.num_captions_per_image):
            loss, acc = self._compute_caption_loss_and_acc(
                img_embed, batch_seq[:, i, :], training=False
            )

            # 3. Update batch loss and batch accuracy
            batch_loss += loss
            batch_acc += acc

        batch_acc /= float(self.num_captions_per_image)

        # 4. Update the trackers
        self.loss_tracker.update_state(batch_loss)
        self.acc_tracker.update_state(batch_acc)

        # 5. Return the loss and accuracy values
        return {"loss": self.loss_tracker.result(), "acc": self.acc_tracker.result()}

    @property
    def metrics(self):
        # We need to list our metrics here so the `reset_states()` can be
        # called automatically.
        return [self.loss_tracker, self.acc_tracker]


cnn_model = get_cnn_model()
encoder = TransformerEncoderBlock(embed_dim=EMBED_DIM, dense_dim=FF_DIM, num_heads=1)
decoder = TransformerDecoderBlock(embed_dim=EMBED_DIM, ff_dim=FF_DIM, num_heads=2)
caption_model = ImageCaptioningModel(
    cnn_model=cnn_model, encoder=encoder, decoder=decoder, image_aug=image_augmentation,
)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 2s 0us/step

# %% [markdown]
# ## Model training

# %%
# Define the loss function
cross_entropy = keras.losses.SparseCategoricalCrossentropy(
    from_logits=False, reduction="none"
)

# EarlyStopping criteria
early_stopping = keras.callbacks.EarlyStopping(patience=3, restore_best_weights=True)


# Learning Rate Scheduler for the optimizer
class LRSchedule(keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, post_warmup_learning_rate, warmup_steps):
        super().__init__()
        self.post_warmup_learning_rate = post_warmup_learning_rate
        self.warmup_steps = warmup_steps

    def __call__(self, step):
        global_step = tf.cast(step, tf.float32)
        warmup_steps = tf.cast(self.warmup_steps, tf.float32)
        warmup_progress = global_step / warmup_steps
        warmup_learning_rate = self.post_warmup_learning_rate * warmup_progress
        return tf.cond(
            global_step < warmup_steps,
            lambda: warmup_learning_rate,
            lambda: self.post_warmup_learning_rate,
        )


# Create a learning rate schedule
num_train_steps = len(train_dataset) * EPOCHS
num_warmup_steps = num_train_steps // 15
lr_schedule = LRSchedule(post_warmup_learning_rate=1e-4, warmup_steps=num_warmup_steps)

# Compile the model
caption_model.compile(optimizer=keras.optimizers.Adam(lr_schedule), loss=cross_entropy)

# Fit the model

caption_model.fit(
    train_dataset,
    epochs=EPOCHS,
    validation_data=valid_dataset,
)
#caption_model.fit(
 #   train_dataset,
 #   epochs=EPOCHS,
 #   validation_data=valid_dataset,
 #   callbacks=[early_stopping],
#)
# Out:
# Epoch 1/300
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# 3/3 [==============================] - 96s 19s/step - loss: 28.0833 - acc: 0.0000e+00 - val_loss: 27.7647 - val_acc: 0.0000e+00
# Epoch 2/300
# 3/3 [==============================] - 5s 1s/step - loss: 27.6466 - acc: 2.6709e-04 - val_loss: 26.9964 - val_acc: 0.0000e+00
# Epoch 3/300
# 3/3 [==============================] - 5s 1s/step - loss: 26.6572 - acc: 0.0200 - val_loss: 25.5440 - val_acc: 0.1743
# Epoch 4/300
# 3/3 [==============================] - 4s 1s/step - loss: 25.0802 - acc: 0.1083 - val_loss: 23.4334 - val_acc: 0.1769
# Epoch 5/300
# 3/3 [==============================] - 4s 1s/step - loss: 22.9572 - acc: 0.1583 - val_loss: 21.2609 - val_acc: 0.1883
# Epoch 6/300
# 3/3 [==============================] - 5s 1s/step - loss: 20.7797 - acc: 0.1614 - val_loss: 19.0428 - val_acc: 0.1912
# Epoch 7/300
# 3/3 [==============================] - 4s 1s/step - loss: 18.4968 - acc: 0.1785 - val_loss: 16.7365 - val_acc: 0.1961
# Epoch 8/300
# 3/3 [==============================] - 5s 1s/step - loss: 16.2748 - acc: 0.1894 - val_loss: 14.7752 - val_acc: 0.2131
# Epoch 9/300
# 3/3 [==============================] - 4s 1s/step - loss: 14.4099 - acc: 0.2143 - val_loss: 13.3766 - val_acc: 0.2324
# Epoch 10/300
# 3/3 [==============================] - 4s 1s/step - loss: 13.2359 - acc: 0.2242 - val_loss: 12.4463 - val_acc: 0.2408
# Epoch 11/300
# 3/3 [==============================] - 4s 1s/step - loss: 12.4511 - acc: 0.2331 - val_loss: 11.8113 - val_acc: 0.2543
# Epoch 12/300
# 3/3 [==============================] - 4s 913ms/step - loss: 11.9021 - acc: 0.2383 - val_loss: 11.3154 - val_acc: 0.2649
# Epoch 13/300
# 3/3 [==============================] - 4s 1s/step - loss: 11.4412 - acc: 0.2500 - val_loss: 10.8956 - val_acc: 0.2798
# Epoch 14/300
# 3/3 [==============================] - 4s 923ms/step - loss: 11.2114 - acc: 0.2686 - val_loss: 10.5303 - val_acc: 0.3088
# Epoch 15/300
# 3/3 [==============================] - 4s 996ms/step - loss: 10.8586 - acc: 0.2923 - val_loss: 10.2069 - val_acc: 0.3345
# Epoch 16/300
# 3/3 [==============================] - 4s 1s/step - loss: 10.3562 - acc: 0.3098 - val_loss: 9.8972 - val_acc: 0.3584
# Epoch 17/300
# 3/3 [==============================] - 4s 1s/step - loss: 10.1113 - acc: 0.3194 - val_loss: 9.5855 - val_acc: 0.3758
# Epoch 18/300
# 3/3 [==============================] - 4s 1s/step - loss: 9.8326 - acc: 0.3331 - val_loss: 9.3064 - val_acc: 0.3983
# Epoch 19/300
# 3/3 [==============================] - 5s 1s/step - loss: 9.6750 - acc: 0.3470 - val_loss: 9.0529 - val_acc: 0.4118
# Epoch 20/300
# 3/3 [==============================] - 4s 1s/step - loss: 9.3413 - acc: 0.3628 - val_loss: 8.8007 - val_acc: 0.4192
# Epoch 21/300
# 3/3 [==============================] - 4s 1s/step - loss: 9.0651 - acc: 0.3802 - val_loss: 8.5411 - val_acc: 0.4322
# Epoch 22/300
# 3/3 [==============================] - 5s 1s/step - loss: 8.7251 - acc: 0.3888 - val_loss: 8.3608 - val_acc: 0.4349
# Epoch 23/300
# 3/3 [==============================] - 4s 1s/step - loss: 8.6487 - acc: 0.3868 - val_loss: 8.1890 - val_acc: 0.4283
# Epoch 24/300
# 3/3 [==============================] - 4s 1s/step - loss: 8.2712 - acc: 0.4047 - val_loss: 7.9857 - val_acc: 0.4445
# Epoch 25/300
# 3/3 [==============================] - 4s 918ms/step - loss: 8.2713 - acc: 0.4106 - val_loss: 7.8111 - val_acc: 0.4462
# Epoch 26/300
# 3/3 [==============================] - 4s 1000ms/step - loss: 8.1927 - acc: 0.4161 - val_loss: 7.6471 - val_acc: 0.4511
# Epoch 27/300
# 3/3 [==============================] - 4s 1s/step - loss: 7.7130 - acc: 0.4269 - val_loss: 7.4887 - val_acc: 0.4571
# Epoch 28/300
# 3/3 [==============================] - 4s 916ms/step - loss: 7.7067 - acc: 0.4354 - val_loss: 7.3417 - val_acc: 0.4559
# Epoch 29/300
# 3/3 [==============================] - 4s 917ms/step - loss: 7.3847 - acc: 0.4404 - val_loss: 7.1995 - val_acc: 0.4706
# Epoch 30/300
# 3/3 [==============================] - 5s 1s/step - loss: 7.3806 - acc: 0.4423 - val_loss: 7.0689 - val_acc: 0.4751
# Epoch 31/300
# 3/3 [==============================] - 4s 908ms/step - loss: 7.2884 - acc: 0.4480 - val_loss: 7.0109 - val_acc: 0.4680
# Epoch 32/300
# 3/3 [==============================] - 4s 1s/step - loss: 6.9774 - acc: 0.4538 - val_loss: 6.8827 - val_acc: 0.4765
# Epoch 33/300
# 3/3 [==============================] - 5s 1s/step - loss: 6.9614 - acc: 0.4605 - val_loss: 6.7641 - val_acc: 0.4730
# Epoch 34/300
# 3/3 [==============================] - 4s 923ms/step - loss: 6.6822 - acc: 0.4704 - val_loss: 6.6247 - val_acc: 0.4864
# Epoch 35/300
# 3/3 [==============================] - 4s 1s/step - loss: 6.6452 - acc: 0.4789 - val_loss: 6.5579 - val_acc: 0.4969
# Epoch 36/300
# 3/3 [==============================] - 4s 1s/step - loss: 6.5772 - acc: 0.4756 - val_loss: 6.4601 - val_acc: 0.4986
# Epoch 37/300
# 3/3 [==============================] - 4s 1s/step - loss: 6.5180 - acc: 0.4825 - val_loss: 6.3753 - val_acc: 0.4993
# Epoch 38/300
# 3/3 [==============================] - 5s 1s/step - loss: 6.3101 - acc: 0.4963 - val_loss: 6.3005 - val_acc: 0.5055
# Epoch 39/300
# 3/3 [==============================] - 4s 913ms/step - loss: 6.2147 - acc: 0.4952 - val_loss: 6.2230 - val_acc: 0.5188
# Epoch 40/300
# 3/3 [==============================] - 4s 1s/step - loss: 6.0357 - acc: 0.4971 - val_loss: 6.1504 - val_acc: 0.5087
# Epoch 41/300
# 3/3 [==============================] - 5s 1s/step - loss: 5.9963 - acc: 0.5002 - val_loss: 6.1156 - val_acc: 0.5127
# Epoch 42/300
# 3/3 [==============================] - 4s 932ms/step - loss: 5.9285 - acc: 0.5057 - val_loss: 6.0416 - val_acc: 0.5145
# Epoch 43/300
# 3/3 [==============================] - 4s 929ms/step - loss: 5.7173 - acc: 0.5123 - val_loss: 5.9549 - val_acc: 0.5236
# Epoch 44/300
# 3/3 [==============================] - 5s 1s/step - loss: 5.6055 - acc: 0.5226 - val_loss: 5.8911 - val_acc: 0.5280
# Epoch 45/300
# 3/3 [==============================] - 4s 912ms/step - loss: 5.6310 - acc: 0.5197 - val_loss: 5.8320 - val_acc: 0.5268
# Epoch 46/300
# 3/3 [==============================] - 4s 916ms/step - loss: 5.5784 - acc: 0.5286 - val_loss: 5.8021 - val_acc: 0.5274
# Epoch 47/300
# 3/3 [==============================] - 4s 1s/step - loss: 5.3925 - acc: 0.5335 - val_loss: 5.7329 - val_acc: 0.5211
# Epoch 48/300
# 3/3 [==============================] - 4s 994ms/step - loss: 5.3483 - acc: 0.5420 - val_loss: 5.6768 - val_acc: 0.5337
# Epoch 49/300
# 3/3 [==============================] - 4s 995ms/step - loss: 5.2211 - acc: 0.5455 - val_loss: 5.6084 - val_acc: 0.5294
# Epoch 50/300
# 3/3 [==============================] - 5s 1s/step - loss: 5.3066 - acc: 0.5410 - val_loss: 5.5897 - val_acc: 0.5329
# Epoch 51/300
# 3/3 [==============================] - 4s 1s/step - loss: 5.2106 - acc: 0.5530 - val_loss: 5.5440 - val_acc: 0.5370
# Epoch 52/300
# 3/3 [==============================] - 4s 923ms/step - loss: 5.0906 - acc: 0.5494 - val_loss: 5.5074 - val_acc: 0.5391
# Epoch 53/300
# 3/3 [==============================] - 5s 1s/step - loss: 5.0374 - acc: 0.5626 - val_loss: 5.4798 - val_acc: 0.5373
# Epoch 54/300
# 3/3 [==============================] - 4s 909ms/step - loss: 4.9592 - acc: 0.5736 - val_loss: 5.4365 - val_acc: 0.5418
# Epoch 55/300
# 3/3 [==============================] - 4s 1s/step - loss: 4.8947 - acc: 0.5731 - val_loss: 5.3851 - val_acc: 0.5419
# Epoch 56/300
# 3/3 [==============================] - 5s 1s/step - loss: 4.6928 - acc: 0.5763 - val_loss: 5.3788 - val_acc: 0.5411
# Epoch 57/300
# 3/3 [==============================] - 4s 1s/step - loss: 4.7112 - acc: 0.5802 - val_loss: 5.3534 - val_acc: 0.5434
# Epoch 58/300
# 3/3 [==============================] - 4s 997ms/step - loss: 4.6502 - acc: 0.5811 - val_loss: 5.2942 - val_acc: 0.5461
# Epoch 59/300
# 3/3 [==============================] - 4s 991ms/step - loss: 4.6033 - acc: 0.5869 - val_loss: 5.2528 - val_acc: 0.5491
# Epoch 60/300
# 3/3 [==============================] - 4s 927ms/step - loss: 4.5073 - acc: 0.5898 - val_loss: 5.2480 - val_acc: 0.5498
# Epoch 61/300
# 3/3 [==============================] - 4s 1s/step - loss: 4.4832 - acc: 0.5903 - val_loss: 5.2038 - val_acc: 0.5474
# Epoch 62/300
# 3/3 [==============================] - 4s 1s/step - loss: 4.3330 - acc: 0.5951 - val_loss: 5.1481 - val_acc: 0.5553
# Epoch 63/300
# 3/3 [==============================] - 4s 1s/step - loss: 4.4223 - acc: 0.6009 - val_loss: 5.1131 - val_acc: 0.5701
# Epoch 64/300
# 3/3 [==============================] - 5s 1s/step - loss: 4.3265 - acc: 0.6006 - val_loss: 5.1312 - val_acc: 0.5566
# Epoch 65/300
# 3/3 [==============================] - 4s 1s/step - loss: 4.2727 - acc: 0.6123 - val_loss: 5.0602 - val_acc: 0.5636
# Epoch 66/300
# 3/3 [==============================] - 4s 1s/step - loss: 4.2789 - acc: 0.6153 - val_loss: 5.0461 - val_acc: 0.5602
# Epoch 67/300
# 3/3 [==============================] - 4s 1s/step - loss: 4.0941 - acc: 0.6194 - val_loss: 5.0249 - val_acc: 0.5511
# Epoch 68/300
# 3/3 [==============================] - 4s 998ms/step - loss: 4.0383 - acc: 0.6129 - val_loss: 4.9875 - val_acc: 0.5603
# Epoch 69/300
# 3/3 [==============================] - 4s 1s/step - loss: 4.0169 - acc: 0.6280 - val_loss: 4.9591 - val_acc: 0.5651
# Epoch 70/300
# 3/3 [==============================] - 5s 995ms/step - loss: 4.0671 - acc: 0.6312 - val_loss: 4.9129 - val_acc: 0.5601
# Epoch 71/300
# 3/3 [==============================] - 4s 1s/step - loss: 3.8783 - acc: 0.6298 - val_loss: 4.8662 - val_acc: 0.5667
# Epoch 72/300
# 3/3 [==============================] - 4s 1s/step - loss: 3.9732 - acc: 0.6333 - val_loss: 4.8663 - val_acc: 0.5759
# Epoch 73/300
# 3/3 [==============================] - 4s 967ms/step - loss: 3.7941 - acc: 0.6385 - val_loss: 4.8665 - val_acc: 0.5722
# Epoch 74/300
# 3/3 [==============================] - 4s 907ms/step - loss: 3.8585 - acc: 0.6380 - val_loss: 4.8228 - val_acc: 0.5835
# Epoch 75/300
# 3/3 [==============================] - 4s 1s/step - loss: 3.7064 - acc: 0.6484 - val_loss: 4.7996 - val_acc: 0.5749
# Epoch 76/300
# 3/3 [==============================] - 5s 1s/step - loss: 3.7158 - acc: 0.6480 - val_loss: 4.7709 - val_acc: 0.5863
# Epoch 77/300
# 3/3 [==============================] - 4s 999ms/step - loss: 3.5929 - acc: 0.6483 - val_loss: 4.7736 - val_acc: 0.5844
# Epoch 78/300
# 3/3 [==============================] - 4s 1s/step - loss: 3.6444 - acc: 0.6506 - val_loss: 4.7171 - val_acc: 0.5837
# Epoch 79/300
# 3/3 [==============================] - 5s 1s/step - loss: 3.5810 - acc: 0.6640 - val_loss: 4.7408 - val_acc: 0.5880
# Epoch 80/300
# 3/3 [==============================] - 4s 934ms/step - loss: 3.6430 - acc: 0.6596 - val_loss: 4.7393 - val_acc: 0.5850
# Epoch 81/300
# 3/3 [==============================] - 4s 987ms/step - loss: 3.5923 - acc: 0.6622 - val_loss: 4.7414 - val_acc: 0.5791
# Epoch 82/300
# 3/3 [==============================] - 5s 992ms/step - loss: 3.4753 - acc: 0.6583 - val_loss: 4.7361 - val_acc: 0.5820
# Epoch 83/300
# 3/3 [==============================] - 4s 1s/step - loss: 3.3152 - acc: 0.6678 - val_loss: 4.6915 - val_acc: 0.5853
# Epoch 84/300
# 3/3 [==============================] - 4s 1s/step - loss: 3.4175 - acc: 0.6783 - val_loss: 4.7229 - val_acc: 0.5838
# Epoch 85/300
# 3/3 [==============================] - 4s 1s/step - loss: 3.3071 - acc: 0.6799 - val_loss: 4.7423 - val_acc: 0.5887
# Epoch 86/300
# 3/3 [==============================] - 4s 916ms/step - loss: 3.2776 - acc: 0.6765 - val_loss: 4.7093 - val_acc: 0.5899
# Epoch 87/300
# 3/3 [==============================] - 4s 1s/step - loss: 3.3145 - acc: 0.6795 - val_loss: 4.7150 - val_acc: 0.5799
# Epoch 88/300
# 3/3 [==============================] - 4s 994ms/step - loss: 3.1848 - acc: 0.6807 - val_loss: 4.6872 - val_acc: 0.5865
# Epoch 89/300
# 3/3 [==============================] - 4s 919ms/step - loss: 3.1176 - acc: 0.6884 - val_loss: 4.6584 - val_acc: 0.5985
# Epoch 90/300
# 3/3 [==============================] - 4s 1s/step - loss: 3.2032 - acc: 0.6887 - val_loss: 4.6181 - val_acc: 0.6040
# Epoch 91/300
# 3/3 [==============================] - 4s 915ms/step - loss: 3.1418 - acc: 0.6976 - val_loss: 4.6032 - val_acc: 0.5935
# Epoch 92/300
# 3/3 [==============================] - 4s 938ms/step - loss: 2.9756 - acc: 0.7014 - val_loss: 4.6089 - val_acc: 0.5922
# Epoch 93/300
# 3/3 [==============================] - 5s 1s/step - loss: 3.0830 - acc: 0.6910 - val_loss: 4.5536 - val_acc: 0.6003
# Epoch 94/300
# 3/3 [==============================] - 4s 913ms/step - loss: 3.0780 - acc: 0.7041 - val_loss: 4.5417 - val_acc: 0.6047
# Epoch 95/300
# 3/3 [==============================] - 4s 905ms/step - loss: 2.9341 - acc: 0.7027 - val_loss: 4.5963 - val_acc: 0.5954
# Epoch 96/300
# 3/3 [==============================] - 5s 995ms/step - loss: 2.9655 - acc: 0.7042 - val_loss: 4.5876 - val_acc: 0.5925
# Epoch 97/300
# 3/3 [==============================] - 4s 996ms/step - loss: 2.7871 - acc: 0.7229 - val_loss: 4.5756 - val_acc: 0.5981
# Epoch 98/300
# 3/3 [==============================] - 4s 1s/step - loss: 2.8994 - acc: 0.7098 - val_loss: 4.5814 - val_acc: 0.6118
# Epoch 99/300
# 3/3 [==============================] - 4s 981ms/step - loss: 3.0178 - acc: 0.7030 - val_loss: 4.5713 - val_acc: 0.5974
# Epoch 100/300
# 3/3 [==============================] - 4s 921ms/step - loss: 2.7713 - acc: 0.7188 - val_loss: 4.5440 - val_acc: 0.6044
# Epoch 101/300
# 3/3 [==============================] - 4s 1s/step - loss: 2.6629 - acc: 0.7320 - val_loss: 4.5508 - val_acc: 0.6004
# Epoch 102/300
# 3/3 [==============================] - 4s 913ms/step - loss: 2.7873 - acc: 0.7269 - val_loss: 4.5761 - val_acc: 0.6004
# Epoch 103/300
# 3/3 [==============================] - 4s 996ms/step - loss: 2.7707 - acc: 0.7225 - val_loss: 4.5070 - val_acc: 0.6067
# Epoch 104/300
# 3/3 [==============================] - 4s 899ms/step - loss: 2.7143 - acc: 0.7257 - val_loss: 4.5206 - val_acc: 0.5981
# Epoch 105/300
# 3/3 [==============================] - 4s 918ms/step - loss: 2.6332 - acc: 0.7293 - val_loss: 4.4971 - val_acc: 0.6040
# Epoch 106/300
# 3/3 [==============================] - 4s 1s/step - loss: 2.6613 - acc: 0.7247 - val_loss: 4.5531 - val_acc: 0.6082
# Epoch 107/300
# 3/3 [==============================] - 4s 916ms/step - loss: 2.6464 - acc: 0.7274 - val_loss: 4.5345 - val_acc: 0.6026
# Epoch 108/300
# 3/3 [==============================] - 4s 912ms/step - loss: 2.6906 - acc: 0.7267 - val_loss: 4.5790 - val_acc: 0.5958
# Epoch 109/300
# 3/3 [==============================] - 4s 1s/step - loss: 2.5538 - acc: 0.7418 - val_loss: 4.5162 - val_acc: 0.6095
# Epoch 110/300
# 3/3 [==============================] - 4s 907ms/step - loss: 2.5700 - acc: 0.7350 - val_loss: 4.5173 - val_acc: 0.6047
# Epoch 111/300
# 3/3 [==============================] - 4s 986ms/step - loss: 2.4333 - acc: 0.7499 - val_loss: 4.5108 - val_acc: 0.6113
# Epoch 112/300
# 3/3 [==============================] - 5s 1s/step - loss: 2.4338 - acc: 0.7496 - val_loss: 4.5494 - val_acc: 0.6087
# Epoch 113/300
# 3/3 [==============================] - 4s 918ms/step - loss: 2.4284 - acc: 0.7518 - val_loss: 4.5553 - val_acc: 0.6054
# Epoch 114/300
# 3/3 [==============================] - 4s 915ms/step - loss: 2.4760 - acc: 0.7404 - val_loss: 4.5059 - val_acc: 0.6017
# Epoch 115/300
# 3/3 [==============================] - 4s 919ms/step - loss: 2.4361 - acc: 0.7511 - val_loss: 4.5217 - val_acc: 0.6095
# Epoch 116/300
# 3/3 [==============================] - 4s 988ms/step - loss: 2.4941 - acc: 0.7505 - val_loss: 4.4578 - val_acc: 0.6130
# Epoch 117/300
# 3/3 [==============================] - 4s 984ms/step - loss: 2.3838 - acc: 0.7522 - val_loss: 4.5019 - val_acc: 0.6137
# Epoch 118/300
# 3/3 [==============================] - 4s 991ms/step - loss: 2.3535 - acc: 0.7497 - val_loss: 4.4796 - val_acc: 0.6138
# Epoch 119/300
# 3/3 [==============================] - 4s 922ms/step - loss: 2.3105 - acc: 0.7581 - val_loss: 4.5486 - val_acc: 0.6103
# Epoch 120/300
# 3/3 [==============================] - 4s 990ms/step - loss: 2.3249 - acc: 0.7589 - val_loss: 4.4856 - val_acc: 0.6130
# Epoch 121/300
# 3/3 [==============================] - 5s 1s/step - loss: 2.2686 - acc: 0.7680 - val_loss: 4.5195 - val_acc: 0.6061
# Epoch 122/300
# 3/3 [==============================] - 4s 901ms/step - loss: 2.2715 - acc: 0.7653 - val_loss: 4.4927 - val_acc: 0.6158
# Epoch 123/300
# 3/3 [==============================] - 4s 1s/step - loss: 2.2117 - acc: 0.7606 - val_loss: 4.4820 - val_acc: 0.6125
# Epoch 124/300
# 3/3 [==============================] - 4s 1s/step - loss: 2.1587 - acc: 0.7715 - val_loss: 4.5275 - val_acc: 0.6116
# Epoch 125/300
# 3/3 [==============================] - 4s 920ms/step - loss: 2.1265 - acc: 0.7700 - val_loss: 4.5111 - val_acc: 0.6095
# Epoch 126/300
# 3/3 [==============================] - 3s 910ms/step - loss: 2.1552 - acc: 0.7728 - val_loss: 4.4941 - val_acc: 0.6111
# Epoch 127/300
# 3/3 [==============================] - 4s 1s/step - loss: 2.1548 - acc: 0.7718 - val_loss: 4.4843 - val_acc: 0.6121
# Epoch 128/300
# 3/3 [==============================] - 4s 1s/step - loss: 2.0515 - acc: 0.7781 - val_loss: 4.5062 - val_acc: 0.6163
# Epoch 129/300
# 3/3 [==============================] - 4s 906ms/step - loss: 2.1615 - acc: 0.7796 - val_loss: 4.5055 - val_acc: 0.6073
# Epoch 130/300
# 3/3 [==============================] - 5s 1s/step - loss: 2.0627 - acc: 0.7787 - val_loss: 4.5448 - val_acc: 0.6193
# Epoch 131/300
# 3/3 [==============================] - 4s 913ms/step - loss: 1.9934 - acc: 0.7856 - val_loss: 4.4728 - val_acc: 0.6195
# Epoch 132/300
# 3/3 [==============================] - 4s 1s/step - loss: 2.0069 - acc: 0.7892 - val_loss: 4.5082 - val_acc: 0.6191
# Epoch 133/300
# 3/3 [==============================] - 4s 1s/step - loss: 2.0459 - acc: 0.7851 - val_loss: 4.4911 - val_acc: 0.6185
# Epoch 134/300
# 3/3 [==============================] - 4s 930ms/step - loss: 1.9830 - acc: 0.7881 - val_loss: 4.4890 - val_acc: 0.6161
# Epoch 135/300
# 3/3 [==============================] - 4s 1s/step - loss: 2.0164 - acc: 0.7877 - val_loss: 4.5645 - val_acc: 0.6150
# Epoch 136/300
# 3/3 [==============================] - 4s 1s/step - loss: 1.9424 - acc: 0.7905 - val_loss: 4.5127 - val_acc: 0.6143
# Epoch 137/300
# 3/3 [==============================] - 4s 1s/step - loss: 1.8929 - acc: 0.7843 - val_loss: 4.5109 - val_acc: 0.6140
# Epoch 138/300
# 3/3 [==============================] - 4s 988ms/step - loss: 1.9188 - acc: 0.7884 - val_loss: 4.5712 - val_acc: 0.6110
# Epoch 139/300
# 3/3 [==============================] - 4s 902ms/step - loss: 1.9313 - acc: 0.7933 - val_loss: 4.5705 - val_acc: 0.6109
# Epoch 140/300
# 3/3 [==============================] - 4s 909ms/step - loss: 1.9216 - acc: 0.7910 - val_loss: 4.5412 - val_acc: 0.6128
# Epoch 141/300
# 3/3 [==============================] - 5s 1s/step - loss: 1.8602 - acc: 0.7980 - val_loss: 4.5545 - val_acc: 0.6131
# Epoch 142/300
# 3/3 [==============================] - 4s 991ms/step - loss: 1.9500 - acc: 0.7926 - val_loss: 4.4988 - val_acc: 0.6200
# Epoch 143/300
# 3/3 [==============================] - 4s 902ms/step - loss: 1.8962 - acc: 0.7927 - val_loss: 4.5579 - val_acc: 0.6194
# Epoch 144/300
# 3/3 [==============================] - 4s 1s/step - loss: 1.8157 - acc: 0.8000 - val_loss: 4.5202 - val_acc: 0.6135
# Epoch 145/300
# 3/3 [==============================] - 4s 973ms/step - loss: 1.7697 - acc: 0.8074 - val_loss: 4.4909 - val_acc: 0.6151
# Epoch 146/300
# 3/3 [==============================] - 4s 1s/step - loss: 1.7606 - acc: 0.7954 - val_loss: 4.5148 - val_acc: 0.6207
# Epoch 147/300
# 3/3 [==============================] - 4s 1s/step - loss: 1.8321 - acc: 0.8052 - val_loss: 4.5246 - val_acc: 0.6161
# Epoch 148/300
# 3/3 [==============================] - 4s 980ms/step - loss: 1.7716 - acc: 0.8069 - val_loss: 4.5276 - val_acc: 0.6195
# Epoch 149/300
# 3/3 [==============================] - 4s 991ms/step - loss: 1.8274 - acc: 0.8053 - val_loss: 4.5741 - val_acc: 0.6207
# Epoch 150/300
# 3/3 [==============================] - 4s 1s/step - loss: 1.7572 - acc: 0.8097 - val_loss: 4.5469 - val_acc: 0.6229
# Epoch 151/300
# 3/3 [==============================] - 3s 901ms/step - loss: 1.7015 - acc: 0.8134 - val_loss: 4.5287 - val_acc: 0.6166
# Epoch 152/300
# 3/3 [==============================] - 3s 895ms/step - loss: 1.7092 - acc: 0.8118 - val_loss: 4.5601 - val_acc: 0.6249
# Epoch 153/300
# 3/3 [==============================] - 4s 1s/step - loss: 1.6234 - acc: 0.8181 - val_loss: 4.5952 - val_acc: 0.6123
# Epoch 154/300
# 3/3 [==============================] - 4s 900ms/step - loss: 1.6560 - acc: 0.8132 - val_loss: 4.5550 - val_acc: 0.6082
# Epoch 155/300
# 3/3 [==============================] - 4s 903ms/step - loss: 1.6504 - acc: 0.8216 - val_loss: 4.5939 - val_acc: 0.6087
# Epoch 156/300
# 3/3 [==============================] - 4s 1000ms/step - loss: 1.6668 - acc: 0.8182 - val_loss: 4.5188 - val_acc: 0.6203
# Epoch 157/300
# 3/3 [==============================] - 3s 899ms/step - loss: 1.6753 - acc: 0.8152 - val_loss: 4.5087 - val_acc: 0.6202
# Epoch 158/300
# 3/3 [==============================] - 4s 995ms/step - loss: 1.6217 - acc: 0.8118 - val_loss: 4.6604 - val_acc: 0.6098
# Epoch 159/300
# 3/3 [==============================] - 5s 1s/step - loss: 1.5710 - acc: 0.8253 - val_loss: 4.5914 - val_acc: 0.6213
# Epoch 160/300
# 3/3 [==============================] - 4s 917ms/step - loss: 1.5736 - acc: 0.8253 - val_loss: 4.5837 - val_acc: 0.6152
# Epoch 161/300
# 3/3 [==============================] - 4s 910ms/step - loss: 1.5878 - acc: 0.8227 - val_loss: 4.5955 - val_acc: 0.6166
# Epoch 162/300
# 3/3 [==============================] - 4s 898ms/step - loss: 1.5698 - acc: 0.8254 - val_loss: 4.5638 - val_acc: 0.6229
# Epoch 163/300
# 3/3 [==============================] - 4s 1s/step - loss: 1.5515 - acc: 0.8262 - val_loss: 4.5918 - val_acc: 0.6163
# Epoch 164/300
# 3/3 [==============================] - 4s 1s/step - loss: 1.5997 - acc: 0.8260 - val_loss: 4.6307 - val_acc: 0.6177
# Epoch 165/300
# 3/3 [==============================] - 3s 899ms/step - loss: 1.5232 - acc: 0.8306 - val_loss: 4.6113 - val_acc: 0.6160
# Epoch 166/300
# 3/3 [==============================] - 4s 906ms/step - loss: 1.5225 - acc: 0.8327 - val_loss: 4.6300 - val_acc: 0.6062
# Epoch 167/300
# 3/3 [==============================] - 4s 1s/step - loss: 1.4869 - acc: 0.8290 - val_loss: 4.6737 - val_acc: 0.6125
# Epoch 168/300
# 3/3 [==============================] - 4s 900ms/step - loss: 1.4469 - acc: 0.8364 - val_loss: 4.6503 - val_acc: 0.6097
# Epoch 169/300
# 3/3 [==============================] - 4s 907ms/step - loss: 1.4384 - acc: 0.8419 - val_loss: 4.6609 - val_acc: 0.6144
# Epoch 170/300
# 3/3 [==============================] - 4s 1s/step - loss: 1.4566 - acc: 0.8314 - val_loss: 4.5955 - val_acc: 0.6250
# Epoch 171/300
# 3/3 [==============================] - 4s 898ms/step - loss: 1.4759 - acc: 0.8364 - val_loss: 4.6293 - val_acc: 0.6126
# Epoch 172/300
# 3/3 [==============================] - 3s 897ms/step - loss: 1.4989 - acc: 0.8287 - val_loss: 4.6569 - val_acc: 0.6196
# Epoch 173/300
# 3/3 [==============================] - 4s 1s/step - loss: 1.4185 - acc: 0.8345 - val_loss: 4.6692 - val_acc: 0.6079
# Epoch 174/300
# 3/3 [==============================] - 4s 988ms/step - loss: 1.4712 - acc: 0.8343 - val_loss: 4.5926 - val_acc: 0.6181
# Epoch 175/300
# 3/3 [==============================] - 4s 1s/step - loss: 1.4767 - acc: 0.8308 - val_loss: 4.6243 - val_acc: 0.6160
# Epoch 176/300
# 3/3 [==============================] - 5s 1s/step - loss: 1.4012 - acc: 0.8370 - val_loss: 4.6774 - val_acc: 0.6163
# Epoch 177/300
# 3/3 [==============================] - 4s 998ms/step - loss: 1.3856 - acc: 0.8411 - val_loss: 4.6859 - val_acc: 0.6080
# Epoch 178/300
# 3/3 [==============================] - 4s 983ms/step - loss: 1.3663 - acc: 0.8447 - val_loss: 4.6575 - val_acc: 0.6054
# Epoch 179/300
# 3/3 [==============================] - 5s 1s/step - loss: 1.3739 - acc: 0.8438 - val_loss: 4.6749 - val_acc: 0.6143
# Epoch 180/300
# 3/3 [==============================] - 4s 989ms/step - loss: 1.3394 - acc: 0.8410 - val_loss: 4.6499 - val_acc: 0.6162
# Epoch 181/300
# 3/3 [==============================] - 4s 918ms/step - loss: 1.3648 - acc: 0.8431 - val_loss: 4.6763 - val_acc: 0.6190
# Epoch 182/300
# 3/3 [==============================] - 4s 991ms/step - loss: 1.3887 - acc: 0.8458 - val_loss: 4.7593 - val_acc: 0.6144
# Epoch 183/300
# 3/3 [==============================] - 4s 983ms/step - loss: 1.3265 - acc: 0.8514 - val_loss: 4.7706 - val_acc: 0.6114
# Epoch 184/300
# 3/3 [==============================] - 4s 1s/step - loss: 1.3324 - acc: 0.8467 - val_loss: 4.7241 - val_acc: 0.6245
# Epoch 185/300
# 3/3 [==============================] - 4s 993ms/step - loss: 1.3253 - acc: 0.8392 - val_loss: 4.8152 - val_acc: 0.6136
# Epoch 186/300
# 3/3 [==============================] - 3s 895ms/step - loss: 1.3091 - acc: 0.8473 - val_loss: 4.7108 - val_acc: 0.6153
# Epoch 187/300
# 3/3 [==============================] - 4s 986ms/step - loss: 1.2887 - acc: 0.8518 - val_loss: 4.8312 - val_acc: 0.6136
# Epoch 188/300
# 3/3 [==============================] - 4s 989ms/step - loss: 1.2650 - acc: 0.8509 - val_loss: 4.7678 - val_acc: 0.6239
# Epoch 189/300
# 3/3 [==============================] - 4s 983ms/step - loss: 1.2648 - acc: 0.8492 - val_loss: 4.8885 - val_acc: 0.6098
# Epoch 190/300
# 3/3 [==============================] - 4s 1s/step - loss: 1.2727 - acc: 0.8548 - val_loss: 4.7816 - val_acc: 0.6114
# Epoch 191/300
# 3/3 [==============================] - 4s 989ms/step - loss: 1.2824 - acc: 0.8493 - val_loss: 4.7875 - val_acc: 0.6131
# Epoch 192/300
# 3/3 [==============================] - 4s 990ms/step - loss: 1.2680 - acc: 0.8504 - val_loss: 4.7594 - val_acc: 0.6088
# Epoch 193/300
# 3/3 [==============================] - 4s 1s/step - loss: 1.3189 - acc: 0.8495 - val_loss: 4.8588 - val_acc: 0.6061
# Epoch 194/300
# 3/3 [==============================] - 4s 988ms/step - loss: 1.3138 - acc: 0.8444 - val_loss: 4.8750 - val_acc: 0.6132
# Epoch 195/300
# 3/3 [==============================] - 4s 911ms/step - loss: 1.2733 - acc: 0.8520 - val_loss: 4.8679 - val_acc: 0.6122
# Epoch 196/300
# 3/3 [==============================] - 4s 1s/step - loss: 1.2659 - acc: 0.8528 - val_loss: 4.8531 - val_acc: 0.6118
# Epoch 197/300
# 3/3 [==============================] - 4s 901ms/step - loss: 1.2480 - acc: 0.8561 - val_loss: 4.8387 - val_acc: 0.6110
# Epoch 198/300
# 3/3 [==============================] - 4s 982ms/step - loss: 1.1824 - acc: 0.8579 - val_loss: 4.8485 - val_acc: 0.6120
# Epoch 199/300
# 3/3 [==============================] - 4s 1s/step - loss: 1.2176 - acc: 0.8574 - val_loss: 4.8583 - val_acc: 0.6138
# Epoch 200/300
# 3/3 [==============================] - 4s 1s/step - loss: 1.2561 - acc: 0.8540 - val_loss: 4.8767 - val_acc: 0.6137
# Epoch 201/300
# 3/3 [==============================] - 4s 1s/step - loss: 1.2299 - acc: 0.8560 - val_loss: 4.9024 - val_acc: 0.6039
# Epoch 202/300
# 3/3 [==============================] - 4s 999ms/step - loss: 1.2521 - acc: 0.8489 - val_loss: 4.8971 - val_acc: 0.6109
# Epoch 203/300
# 3/3 [==============================] - 4s 1s/step - loss: 1.1604 - acc: 0.8567 - val_loss: 4.9109 - val_acc: 0.6118
# Epoch 204/300
# 3/3 [==============================] - 4s 1s/step - loss: 1.1583 - acc: 0.8600 - val_loss: 4.8720 - val_acc: 0.6146
# Epoch 205/300
# 3/3 [==============================] - 4s 989ms/step - loss: 1.1990 - acc: 0.8540 - val_loss: 4.8408 - val_acc: 0.6153
# Epoch 206/300
# 3/3 [==============================] - 4s 1s/step - loss: 1.1750 - acc: 0.8591 - val_loss: 4.9202 - val_acc: 0.6140
# Epoch 207/300
# 3/3 [==============================] - 3s 902ms/step - loss: 1.1494 - acc: 0.8654 - val_loss: 4.8375 - val_acc: 0.6210
# Epoch 208/300
# 3/3 [==============================] - 4s 988ms/step - loss: 1.1686 - acc: 0.8634 - val_loss: 4.8955 - val_acc: 0.6132
# Epoch 209/300
# 3/3 [==============================] - 4s 1s/step - loss: 1.1394 - acc: 0.8672 - val_loss: 4.8595 - val_acc: 0.6206
# Epoch 210/300
# 3/3 [==============================] - 4s 906ms/step - loss: 1.1534 - acc: 0.8673 - val_loss: 4.8504 - val_acc: 0.6174
# Epoch 211/300
# 3/3 [==============================] - 4s 995ms/step - loss: 1.1708 - acc: 0.8573 - val_loss: 4.9088 - val_acc: 0.6191
# Epoch 212/300
# 3/3 [==============================] - 4s 1s/step - loss: 1.1465 - acc: 0.8618 - val_loss: 4.9109 - val_acc: 0.6225
# Epoch 213/300
# 3/3 [==============================] - 4s 924ms/step - loss: 1.0882 - acc: 0.8726 - val_loss: 4.9442 - val_acc: 0.6156
# Epoch 214/300
# 3/3 [==============================] - 4s 899ms/step - loss: 1.1272 - acc: 0.8667 - val_loss: 4.9356 - val_acc: 0.6120
# Epoch 215/300
# 3/3 [==============================] - 4s 1s/step - loss: 1.1020 - acc: 0.8610 - val_loss: 4.9068 - val_acc: 0.6145
# Epoch 216/300
# 3/3 [==============================] - 3s 908ms/step - loss: 1.1181 - acc: 0.8684 - val_loss: 4.8698 - val_acc: 0.6137
# Epoch 217/300
# 3/3 [==============================] - 4s 993ms/step - loss: 1.1015 - acc: 0.8672 - val_loss: 4.9260 - val_acc: 0.6130
# Epoch 218/300
# 3/3 [==============================] - 4s 1s/step - loss: 1.1170 - acc: 0.8672 - val_loss: 4.8964 - val_acc: 0.6160
# Epoch 219/300
# 3/3 [==============================] - 4s 897ms/step - loss: 1.0962 - acc: 0.8720 - val_loss: 4.8901 - val_acc: 0.6197
# Epoch 220/300
# 3/3 [==============================] - 4s 980ms/step - loss: 1.0629 - acc: 0.8705 - val_loss: 4.9586 - val_acc: 0.6176
# Epoch 221/300
# 3/3 [==============================] - 5s 1s/step - loss: 1.0821 - acc: 0.8724 - val_loss: 4.9844 - val_acc: 0.6135
# Epoch 222/300
# 3/3 [==============================] - 4s 991ms/step - loss: 1.0196 - acc: 0.8680 - val_loss: 5.0286 - val_acc: 0.6102
# Epoch 223/300
# 3/3 [==============================] - 4s 997ms/step - loss: 1.0807 - acc: 0.8688 - val_loss: 5.0501 - val_acc: 0.6145
# Epoch 224/300
# 3/3 [==============================] - 5s 1s/step - loss: 1.0745 - acc: 0.8702 - val_loss: 4.9557 - val_acc: 0.6076
# Epoch 225/300
# 3/3 [==============================] - 4s 997ms/step - loss: 1.0599 - acc: 0.8739 - val_loss: 4.9644 - val_acc: 0.6118
# Epoch 226/300
# 3/3 [==============================] - 3s 900ms/step - loss: 1.0142 - acc: 0.8764 - val_loss: 4.9418 - val_acc: 0.6175
# Epoch 227/300
# 3/3 [==============================] - 4s 894ms/step - loss: 1.0490 - acc: 0.8758 - val_loss: 5.0185 - val_acc: 0.6168
# Epoch 228/300
# 3/3 [==============================] - 4s 999ms/step - loss: 1.0368 - acc: 0.8745 - val_loss: 4.9310 - val_acc: 0.6310
# Epoch 229/300
# 3/3 [==============================] - 4s 990ms/step - loss: 1.0220 - acc: 0.8688 - val_loss: 4.9809 - val_acc: 0.6347
# Epoch 230/300
# 3/3 [==============================] - 4s 990ms/step - loss: 0.9882 - acc: 0.8723 - val_loss: 4.9861 - val_acc: 0.6210
# Epoch 231/300
# 3/3 [==============================] - 4s 984ms/step - loss: 1.0440 - acc: 0.8700 - val_loss: 5.0069 - val_acc: 0.6281
# Epoch 232/300
# 3/3 [==============================] - 4s 1s/step - loss: 1.0297 - acc: 0.8706 - val_loss: 5.0679 - val_acc: 0.6210
# Epoch 233/300
# 3/3 [==============================] - 5s 1s/step - loss: 1.0164 - acc: 0.8770 - val_loss: 5.0468 - val_acc: 0.6247
# Epoch 234/300
# 3/3 [==============================] - 4s 984ms/step - loss: 0.9844 - acc: 0.8780 - val_loss: 5.0041 - val_acc: 0.6173
# Epoch 235/300
# 3/3 [==============================] - 4s 979ms/step - loss: 0.9878 - acc: 0.8763 - val_loss: 4.9776 - val_acc: 0.6292
# Epoch 236/300
# 3/3 [==============================] - 4s 902ms/step - loss: 0.9661 - acc: 0.8830 - val_loss: 5.0609 - val_acc: 0.6261
# Epoch 237/300
# 3/3 [==============================] - 4s 896ms/step - loss: 1.0363 - acc: 0.8747 - val_loss: 5.0190 - val_acc: 0.6269
# Epoch 238/300
# 3/3 [==============================] - 5s 1s/step - loss: 0.9445 - acc: 0.8749 - val_loss: 5.0754 - val_acc: 0.6203
# Epoch 239/300
# 3/3 [==============================] - 3s 905ms/step - loss: 0.9207 - acc: 0.8849 - val_loss: 5.0804 - val_acc: 0.6243
# Epoch 240/300
# 3/3 [==============================] - 3s 896ms/step - loss: 0.9912 - acc: 0.8739 - val_loss: 5.1106 - val_acc: 0.6206
# Epoch 241/300
# 3/3 [==============================] - 5s 1s/step - loss: 0.9413 - acc: 0.8840 - val_loss: 5.1105 - val_acc: 0.6190
# Epoch 242/300
# 3/3 [==============================] - 4s 996ms/step - loss: 0.9382 - acc: 0.8801 - val_loss: 5.0104 - val_acc: 0.6297
# Epoch 243/300
# 3/3 [==============================] - 4s 931ms/step - loss: 0.9761 - acc: 0.8757 - val_loss: 5.0521 - val_acc: 0.6238
# Epoch 244/300
# 3/3 [==============================] - 4s 944ms/step - loss: 0.9478 - acc: 0.8830 - val_loss: 5.0739 - val_acc: 0.6210
# Epoch 245/300
# 3/3 [==============================] - 5s 1s/step - loss: 0.9179 - acc: 0.8852 - val_loss: 5.0929 - val_acc: 0.6233
# Epoch 246/300
# 3/3 [==============================] - 4s 996ms/step - loss: 0.9730 - acc: 0.8789 - val_loss: 5.0689 - val_acc: 0.6232
# Epoch 247/300
# 3/3 [==============================] - 4s 994ms/step - loss: 0.9391 - acc: 0.8845 - val_loss: 5.0713 - val_acc: 0.6328
# Epoch 248/300
# 3/3 [==============================] - 4s 992ms/step - loss: 0.8877 - acc: 0.8856 - val_loss: 5.0811 - val_acc: 0.6325
# Epoch 249/300
# 3/3 [==============================] - 4s 1s/step - loss: 0.9346 - acc: 0.8816 - val_loss: 5.1132 - val_acc: 0.6220
# Epoch 250/300
# 3/3 [==============================] - 4s 916ms/step - loss: 0.9795 - acc: 0.8769 - val_loss: 5.1239 - val_acc: 0.6263
# Epoch 251/300
# 3/3 [==============================] - 3s 899ms/step - loss: 0.9324 - acc: 0.8832 - val_loss: 5.0860 - val_acc: 0.6198
# Epoch 252/300
# 3/3 [==============================] - 4s 1s/step - loss: 0.9385 - acc: 0.8791 - val_loss: 5.1091 - val_acc: 0.6190
# Epoch 253/300
# 3/3 [==============================] - 4s 913ms/step - loss: 0.9319 - acc: 0.8856 - val_loss: 5.0904 - val_acc: 0.6242
# Epoch 254/300
# 3/3 [==============================] - 3s 897ms/step - loss: 0.9201 - acc: 0.8906 - val_loss: 5.1860 - val_acc: 0.6283
# Epoch 255/300
# 3/3 [==============================] - 4s 1s/step - loss: 0.9583 - acc: 0.8795 - val_loss: 5.1182 - val_acc: 0.6306
# Epoch 256/300
# 3/3 [==============================] - 4s 898ms/step - loss: 0.9075 - acc: 0.8789 - val_loss: 5.1266 - val_acc: 0.6235
# Epoch 257/300
# 3/3 [==============================] - 4s 898ms/step - loss: 0.9056 - acc: 0.8870 - val_loss: 5.1112 - val_acc: 0.6335
# Epoch 258/300
# 3/3 [==============================] - 4s 1s/step - loss: 0.9097 - acc: 0.8835 - val_loss: 5.1666 - val_acc: 0.6298
# Epoch 259/300
# 3/3 [==============================] - 4s 896ms/step - loss: 0.8936 - acc: 0.8887 - val_loss: 5.1185 - val_acc: 0.6284
# Epoch 260/300
# 3/3 [==============================] - 4s 983ms/step - loss: 0.8677 - acc: 0.8892 - val_loss: 5.1705 - val_acc: 0.6204
# Epoch 261/300
# 3/3 [==============================] - 4s 1s/step - loss: 0.9166 - acc: 0.8854 - val_loss: 5.1184 - val_acc: 0.6321
# Epoch 262/300
# 3/3 [==============================] - 4s 920ms/step - loss: 0.8969 - acc: 0.8832 - val_loss: 5.2307 - val_acc: 0.6247
# Epoch 263/300
# 3/3 [==============================] - 3s 906ms/step - loss: 0.8692 - acc: 0.8898 - val_loss: 5.1552 - val_acc: 0.6285
# Epoch 264/300
# 3/3 [==============================] - 4s 1s/step - loss: 0.9131 - acc: 0.8825 - val_loss: 5.1632 - val_acc: 0.6295
# Epoch 265/300
# 3/3 [==============================] - 4s 899ms/step - loss: 0.8380 - acc: 0.8866 - val_loss: 5.1597 - val_acc: 0.6249
# Epoch 266/300
# 3/3 [==============================] - 4s 985ms/step - loss: 0.8481 - acc: 0.8859 - val_loss: 5.1271 - val_acc: 0.6164
# Epoch 267/300
# 3/3 [==============================] - 4s 1s/step - loss: 0.8839 - acc: 0.8848 - val_loss: 5.1653 - val_acc: 0.6221
# Epoch 268/300
# 3/3 [==============================] - 3s 898ms/step - loss: 0.8534 - acc: 0.8894 - val_loss: 5.1821 - val_acc: 0.6321
# Epoch 269/300
# 3/3 [==============================] - 3s 894ms/step - loss: 0.8192 - acc: 0.8924 - val_loss: 5.1301 - val_acc: 0.6280
# Epoch 270/300
# 3/3 [==============================] - 4s 1s/step - loss: 0.8458 - acc: 0.8881 - val_loss: 5.2483 - val_acc: 0.6256
# Epoch 271/300
# 3/3 [==============================] - 4s 990ms/step - loss: 0.8402 - acc: 0.8924 - val_loss: 5.2151 - val_acc: 0.6266
# Epoch 272/300
# 3/3 [==============================] - 4s 998ms/step - loss: 0.8745 - acc: 0.8876 - val_loss: 5.3067 - val_acc: 0.6197
# Epoch 273/300
# 3/3 [==============================] - 4s 995ms/step - loss: 0.8801 - acc: 0.8885 - val_loss: 5.2233 - val_acc: 0.6273
# Epoch 274/300
# 3/3 [==============================] - 4s 999ms/step - loss: 0.8624 - acc: 0.8918 - val_loss: 5.1872 - val_acc: 0.6205
# Epoch 275/300
# 3/3 [==============================] - 4s 1s/step - loss: 0.8510 - acc: 0.8903 - val_loss: 5.2725 - val_acc: 0.6269
# Epoch 276/300
# 3/3 [==============================] - 4s 918ms/step - loss: 0.8372 - acc: 0.8915 - val_loss: 5.2294 - val_acc: 0.6272
# Epoch 277/300
# 3/3 [==============================] - 4s 985ms/step - loss: 0.8166 - acc: 0.8866 - val_loss: 5.2483 - val_acc: 0.6212
# Epoch 278/300
# 3/3 [==============================] - 4s 1s/step - loss: 0.8538 - acc: 0.8896 - val_loss: 5.2795 - val_acc: 0.6251
# Epoch 279/300
# 3/3 [==============================] - 4s 986ms/step - loss: 0.8026 - acc: 0.8955 - val_loss: 5.3005 - val_acc: 0.6269
# Epoch 280/300
# 3/3 [==============================] - 4s 1s/step - loss: 0.7998 - acc: 0.8915 - val_loss: 5.2566 - val_acc: 0.6238
# Epoch 281/300
# 3/3 [==============================] - 4s 1s/step - loss: 0.8128 - acc: 0.8888 - val_loss: 5.2920 - val_acc: 0.6240
# Epoch 282/300
# 3/3 [==============================] - 4s 1s/step - loss: 0.7814 - acc: 0.8917 - val_loss: 5.2951 - val_acc: 0.6250
# Epoch 283/300
# 3/3 [==============================] - 4s 903ms/step - loss: 0.7770 - acc: 0.8994 - val_loss: 5.3144 - val_acc: 0.6270
# Epoch 284/300
# 3/3 [==============================] - 4s 1s/step - loss: 0.8343 - acc: 0.8874 - val_loss: 5.2799 - val_acc: 0.6283
# Epoch 285/300
# 3/3 [==============================] - 4s 991ms/step - loss: 0.7669 - acc: 0.8942 - val_loss: 5.2869 - val_acc: 0.6304
# Epoch 286/300
# 3/3 [==============================] - 4s 1s/step - loss: 0.8165 - acc: 0.8878 - val_loss: 5.3136 - val_acc: 0.6206
# Epoch 287/300
# 3/3 [==============================] - 4s 1s/step - loss: 0.7769 - acc: 0.8987 - val_loss: 5.2715 - val_acc: 0.6277
# Epoch 288/300
# 3/3 [==============================] - 4s 997ms/step - loss: 0.7783 - acc: 0.8908 - val_loss: 5.3124 - val_acc: 0.6286
# Epoch 289/300
# 3/3 [==============================] - 4s 1s/step - loss: 0.8372 - acc: 0.8918 - val_loss: 5.3222 - val_acc: 0.6326
# Epoch 290/300
# 3/3 [==============================] - 4s 1s/step - loss: 0.8155 - acc: 0.8915 - val_loss: 5.3328 - val_acc: 0.6283
# Epoch 291/300
# 3/3 [==============================] - 3s 907ms/step - loss: 0.7831 - acc: 0.9002 - val_loss: 5.3395 - val_acc: 0.6219
# Epoch 292/300
# 3/3 [==============================] - 4s 997ms/step - loss: 0.7791 - acc: 0.8969 - val_loss: 5.4175 - val_acc: 0.6255
# Epoch 293/300
# 3/3 [==============================] - 4s 1s/step - loss: 0.7719 - acc: 0.8961 - val_loss: 5.3576 - val_acc: 0.6263
# Epoch 294/300
# 3/3 [==============================] - 4s 1s/step - loss: 0.7492 - acc: 0.8954 - val_loss: 5.4344 - val_acc: 0.6213
# Epoch 295/300
# 3/3 [==============================] - 4s 995ms/step - loss: 0.7693 - acc: 0.8977 - val_loss: 5.3823 - val_acc: 0.6277
# Epoch 296/300
# 3/3 [==============================] - 4s 1s/step - loss: 0.7862 - acc: 0.8901 - val_loss: 5.4067 - val_acc: 0.6207
# Epoch 297/300
# 3/3 [==============================] - 4s 913ms/step - loss: 0.7476 - acc: 0.8985 - val_loss: 5.3383 - val_acc: 0.6186
# Epoch 298/300
# 3/3 [==============================] - 4s 999ms/step - loss: 0.7660 - acc: 0.8978 - val_loss: 5.3480 - val_acc: 0.6177
# Epoch 299/300
# 3/3 [==============================] - 4s 1s/step - loss: 0.7514 - acc: 0.8937 - val_loss: 5.2985 - val_acc: 0.6235
# Epoch 300/300
# 3/3 [==============================] - 4s 990ms/step - loss: 0.7841 - acc: 0.8989 - val_loss: 5.3189 - val_acc: 0.6294

# %% [markdown]
# ## Check sample predictions

# %%
vocab = vectorization.get_vocabulary()
index_lookup = dict(zip(range(len(vocab)), vocab))
max_decoded_sentence_length = SEQ_LENGTH - 1
valid_images = list(valid_data.keys())


def generate_caption():
    # Select a random image from the validation dataset
    sample_img = np.random.choice(valid_images)

    # Read the image from the disk
    sample_img = decode_and_resize(sample_img)
    img = sample_img.numpy().clip(0, 255).astype(np.uint8)
    plt.imshow(img)
    plt.show()

    # Pass the image to the CNN
    img = tf.expand_dims(sample_img, 0)
    img = caption_model.cnn_model(img)

    # Pass the image features to the Transformer encoder
    encoded_img = caption_model.encoder(img, training=False)

    # Generate the caption using the Transformer decoder
    decoded_caption = "<start> "
    for i in range(max_decoded_sentence_length):
        tokenized_caption = vectorization([decoded_caption])[:, :-1]
        mask = tf.math.not_equal(tokenized_caption, 0)
        predictions = caption_model.decoder(
            tokenized_caption, encoded_img, training=False, mask=mask
        )
        sampled_token_index = np.argmax(predictions[0, i, :])
        sampled_token = index_lookup[sampled_token_index]
        if sampled_token == " <end>":
            break
        decoded_caption += " " + sampled_token

    decoded_caption = decoded_caption.replace("<start> ", "")
    decoded_caption = decoded_caption.replace(" <end>", "").strip()
    print("Predicted Caption: ", decoded_caption)


# Check predictions for a few samples
generate_caption()
generate_caption()
generate_caption()
generate_caption()
# Out:
# Predicted Caption:  vehículo a realiza cambio de carril e impacta al vehículo a otro
# Predicted Caption:  vehículo b gira de carril hacia la derecha para incorporarse a que venía circulando por él y choca contra vehículo b
# Predicted Caption:  vehículo a cruza de carril e impacta en esquina trasera derecha de otro otro
# Predicted Caption:  vehículo a es impactado en lateral izquierdo por vehículo b cuando giraba a la izquierda

# %% [markdown]
# ## End Notes
#
# We saw that the model starts to generate reasonable captions after a few epochs. To keep
# this example easily runnable, we have trained it with a few constraints, like a minimal
# number of attention heads. To improve the predictions, you can try changing these training
# settings and find a good model for your use case.
