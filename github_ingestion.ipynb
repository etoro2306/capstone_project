# %%
# !apt-get install git
# !git config --global user.email "e.torolevano@alum.up.edu.pe"
# !git config --global user.name "etoro2306"
# !git config --global user.password "A00678toro"
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# git is already the newest version (1:2.17.1-1ubuntu0.13).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 20 not upgraded.

# %%
token = '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'
username = 'etoro2306'
repo = 'capstone_project'

# %%
# !git clone https://{token}@github.com/{username}/{repo}
# Out:
# Cloning into 'capstone_project'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.

# %%
# %cd {repo}
# Out:
# /content/capstone_project

# %%
# %ls
# Out:
# README.md

# %%
# !mv '/content/drive/MyDrive/Capstone Project/Project/data' /content/capstone_project

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
#
# 	data/
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add --all

# %%
# !git commit -a -m "Added the folder with all the images available"
# Out:
# [main 3bded54] Added the folder with all the images available
#  108 files changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 data/parte0.jpg
#  create mode 100644 data/parte1.jpg
#  create mode 100644 data/parte10.jpg
#  create mode 100644 data/parte100.jpg
#  create mode 100644 data/parte101.jpg
#  create mode 100644 data/parte102.jpg
#  create mode 100644 data/parte103.jpg
#  create mode 100644 data/parte104.jpg
#  create mode 100644 data/parte105.jpg
#  create mode 100644 data/parte106.jpg
#  create mode 100644 data/parte107.jpg
#  create mode 100644 data/parte11.jpg
#  create mode 100644 data/parte12.jpg
#  create mode 100644 data/parte13.jpg
#  create mode 100644 data/parte14.jpg
#  create mode 100644 data/parte15.jpg
#  create mode 100644 data/parte16.jpg
#  create mode 100644 data/parte17.jpg
#  create mode 100644 data/parte18.jpg
#  create mode 100644 data/parte19.jpg
#  create mode 100644 data/parte2.jpg
#  create mode 100644 data/parte20.jpg
# ...

# %%
# !git remote -v
# Out:
# origin	https://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@github.com/etoro2306/capstone_project (fetch)
# origin	https://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@github.com/etoro2306/capstone_project (push)

# %%
# !git push origin main
# Out:
# Counting objects: 111, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (111/111), done.
# Writing objects: 100% (111/111), 10.32 MiB | 12.06 MiB/s, done.
# Total 111 (delta 4), reused 0 (delta 0)
# remote: Resolving deltas: 100% (4/4), done.
# To https://github.com/etoro2306/capstone_project
#    0d21bf2..3bded54  main -> main

# %%
# %ls
# Out:
# data/  README.md

# %%
# !mv '/content/drive/MyDrive/Capstone Project/Project/data' /content/capstone_project
